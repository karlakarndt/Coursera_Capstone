# %% [markdown]
# # Capstone Project -- Where should we retire?
#
# ## Introduction/Business Problem
#
# Even though retirement may be far into the future for many taking this class, it is not for some of us. In fact, it's right around the corner! In addition, I belong to an organization that helps seniors plan for these big decisions so know a lot of people that need help in their retirement location planning.
#
# There are many factors that affect when to retire such as financial and health. But, "where to live" is also a major decision.  Many choose to live their retirement years from their current residence. Some may become snow birds and live a few weeks or months in a warmer climate while others may travel to foreign destinations.
#
# "Where to call 'home base'" is the focus of this project. For those who desire to relocate from the city they've called "home" for many years, the decision can be daunting. Even cities that seem similar on the surface can lead to different lifestyles and entertainment opportunities.
#
# This project could be generalized to allow for other seniors to plan for their optimal retirement location, but for this project, I want to keep it personal to make it more realistic.  That is, I'm going to focus on my husband's and my hobbies and desires for a retirement location. We know we want to retire in Wisconsin, but we don't know where.
#
# I want to find some specifics to help us make our decision such as the following:
#
# - Fishing. There is a lot of available fishing, but we want to be able to fish for walleye. We also have a boat and need access to a public boat ramp.
#
# - State parks. We hike and camp a lot. I want to explore state parks in my retirement.
#
# Obviously, some of the information above many not be readily available. I will discover in the next part of the assignment on data if I can accomplish the above. If I cannot, I will choose to delve into other types of activities such as restaurants and shopping districts.
#
# Other criteria we are considering at this time:
#
# - Location close to family. We would like to be within 2 hours of Germantown, Wisconsin.
#
# - The city we ultimately chose to call "home" during our retirement needs to have good Italian restaurants. I have Celiac disease and Italian restaurants are generally very accomodating.

# %% [markdown]
# ## Data
#
# Finding data to manipulate is the key. I want to be able to merge the data so that I have one map with all of the information.
#
# Fishing: I found a fish map by type of fish on the DNR website. I was able to download the information I needed into a csv file and I stored it in github. The data included the lakes' latitude and longitude and if it had a boat landing. Basically, it had everything I needed right in one file!
#     - https://dnr.wi.gov/lakes/lakepages/Results.aspx?page=walleye
#     - walleye.csv -- The file on github that I created from the link above.
#
#     The columns in the table are as follows:
#       - 'Waterbody ID Code (WBIC)'
#       - 'Lake Name'
#       - 'Size (Acres)'
#       - 'Official Max Depth'
#       - 'Official Mean Depth'
#       - 'Latitude'
#       - 'Longitude'
#       - 'Public Landing'
#       - 'Public Beach'
#       - 'Public Park'
#       - 'Fish Present'
#       - 'Lake Type'
#       - 'Water Clarity'
#       - 'County'
#
#     The columns I am interested in are the following:
#       - Lake Name -- The name of the lake
#       - Size (Acres) -- We don't want to fish on anything less than 10 acres
#       - Official Max Depth -- We don't want to fish on anything that has a maximum depth of less than 10 feet
#       - Latitude -- The latitude
#       - Longitude -- The longitude
#       - Public Landing -- The value must be 'Yes'
#       - Fish Present -- This isn't necessary. It may seem necessary, but the data was already gathered for lakes that have walleye; therefore, it's redundant.
#
#      I will build a dataframe with the fields listed above from the csv file using pd.read_csv.
#
#      Using that dataframe, I will produce a folium map of all the lakes that meet the criteria.
#
#
# State parks:  The wiki page below lists the state parks in Wisconsin.
#     - https://en.wikipedia.org/wiki/List_of_Wisconsin_state_parks
#
#     - State park name:
#             - I will be able to scrape the names of all the Wisconsin state parks from this page using BeautifulSoup. There's no other information on the page that I can use.
#             - I'll have to clean the data a bit because it lists more than just state parks such as recreation areas. We are not interested in those.
#
#     - After I get the names of the state parks from this page, I'll use geopy.geocoders Nominatim to get the latitude and longitude of the state parks.
#
#     - Using a dataframe with the park names, latitudes, and longitudes, I will generate a map of all the state parks.
#
# Combining the data:  The goal of this part of the project is to combine the two maps so that I can see where there are walleye lakes that are close to state parks so that we can camp and fish. The lake doesn't need to be in the state parks. We just want them close enough for convenience. I then want to find a city or two that are reasonably close (within a couple hours) to that location and also within a couple hours of Germantown (see more information below).
#
# Foursquare:  Finally, once we can peruse the maps of state parks and walleye lakes, we want to find a community to call home that is within 2 hours of Germantown, Wisconsin, that has Italian restaurants. I have Celiac disease and Italian restaurants are usually gluten-free friendly. I will use Foursquare data to find the venues as follows:
#
#     - Find Italian restaurants in the city of choice: Do a Foursquare search using the latitude and longitude of the city of choice.
#     - Create a map around the city of the Italian restaurants.
#     - Choose some Italian restaurants.
#     - Get the restaurant ratings using Foursquare.
#     - Display the tips using Foursquare. Maybe even somebody said they have gluten free food!

# %% [markdown]
# ## Get dependencies

# %%
import pandas as pd # primary data structure library
import folium
from bs4 import BeautifulSoup

# %%
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# %% [markdown]
# ## Get a generic map of Wisconsin to prove I have the right coordinates

# %%
address = 'Wisconsin, United States'

geolocator = Nominatim(user_agent="wi_explorer")
location = geolocator.geocode(address)
wi_latitude = location.latitude
wi_longitude = location.longitude
print('The geograpical coordinates of Wisconsin are {}, {}.'.format(wi_latitude, wi_longitude))
# Out:
# The geograpical coordinates of Wisconsin are 44.4308975, -89.6884637.

# %%
# Create map and display it
wisc_map = folium.Map(location=[wi_latitude, wi_longitude], zoom_start=7)

# Display the map of Wisconsin
wisc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Read the walleye data from the csv file.

# %%
import io
import requests
url="https://raw.githubusercontent.com/karlakarndt/Coursera_Capstone/master/walleye.csv"
s=requests.get(url).content
df_walleye=pd.read_csv(io.StringIO(s.decode('utf-8')))
df_walleye.head(10)
# Out:
#    Waterbody ID Code (WBIC)       Lake Name  Size (Acres) Official Max Depth  \
# 0                   2329600      Alder Lake           264            30 FEET
# 1                    967400   Aldridge Lake           142            12 FEET
# 2                   1494600  Alexander Lake           618            36 FEET
# 3                   2332400  Allequash Lake           406            24 FEET
# 4                    967900       Alma Lake            58            18 FEET
# 5                   2128100    Altoona Lake           720            25 FEET
# 6                    968100       Alva Lake           199            43 FEET
# 7                   2359700     Amacoy Lake           283            20 FEET
# 8                   2268600       Amik Lake           141             8 FEET
# 9                   2858100    Amnicon Lake           390            31 FEET
#
#   Official Mean Depth   Latitude  Longitude Public Landing Public Beach  \
# 0                 NaN  46.088099 -89.819586            Yes           No
# 1                 NaN  45.865941 -89.301276             No           No
# 2                 NaN  45.186975 -89.757128            Yes          Yes
# 3             10 FEET  46.036939 -89.628844            Yes           No
# 4             11 FEET  45.909763 -89.428275            Yes           No
# 5             10 FEET  44.814930 -91.423098            Yes          Yes
# 6                 NaN  45.708207 -89.592769            Yes           No
# 7             13 FEET  45.398658 -91.314590            Yes           No
# 8              5 FEET  45.932361 -90.033338             No           No
# 9             10 FEET  46.477749 -92.061048            Yes           No
#
#   Public Park                                       Fish Present Lake Type  \
# 0         Yes  Musky, Panfish, Largemouth Bass, Smallmouth Ba...  DRAINAGE
# 1         Yes  Panfish, Largemouth Bass, Northern Pike and Wa...   DRAINED
# 2          No  Musky, Panfish, Largemouth Bass, Smallmouth Ba...  DRAINAGE
# 3         Yes  Musky, Panfish, Largemouth Bass, Smallmouth Ba...  DRAINAGE
# 4          No  Musky, Panfish, Largemouth Bass, Smallmouth Ba...   SEEPAGE
# 5         Yes        Musky, Panfish, Smallmouth Bass and Walleye  DRAINAGE
# 6         Yes  Musky, Panfish, Largemouth Bass, Smallmouth Ba...   SEEPAGE
# 7          No  Musky, Panfish, Largemouth Bass, Smallmouth Ba...  DRAINAGE
# 8         Yes  Musky, Panfish, Largemouth Bass, Smallmouth Ba...  DRAINAGE
# 9          No        Musky, Panfish, Largemouth Bass and Walleye  DRAINAGE
#
#   Water Clarity         County
# 0           NaN          Vilas
# 1           Low  Vilas, Oneida
# 2      Moderate        Lincoln
# 3      Moderate          Vilas
# 4      Moderate          Vilas
# 5           Low     Eau Claire
# 6    Very Clear         Oneida
# 7           Low           Rusk
# 8           Low          Vilas
# 9           Low        Douglas

# %% [markdown]
# ## Clean the data

# %%
# See what type of data is in the columns
df_walleye.dtypes
# Out:
# Waterbody ID Code (WBIC)      int64
# Lake Name                    object
# Size (Acres)                  int64
# Official Max Depth           object
# Official Mean Depth          object
# Latitude                    float64
# Longitude                   float64
# Public Landing               object
# Public Beach                 object
# Public Park                  object
# Fish Present                 object
# Lake Type                    object
# Water Clarity                object
# County                       object
# dtype: object

# %%
# Clean up the dataset to drop unnecessary columns 
df_walleye.drop(['Water Clarity','County','Public Park','Public Beach','Official Mean Depth','Waterbody ID Code (WBIC)','Lake Type','Fish Present'], axis=1, inplace=True)
df_walleye.head()
# Out:
#         Lake Name  Size (Acres) Official Max Depth   Latitude  Longitude  \
# 0      Alder Lake           264            30 FEET  46.088099 -89.819586
# 1   Aldridge Lake           142            12 FEET  45.865941 -89.301276
# 2  Alexander Lake           618            36 FEET  45.186975 -89.757128
# 3  Allequash Lake           406            24 FEET  46.036939 -89.628844
# 4       Alma Lake            58            18 FEET  45.909763 -89.428275
#
#   Public Landing
# 0            Yes
# 1             No
# 2            Yes
# 3            Yes
# 4            Yes

# %%
# See if we have any null columns to see if we need to clean any of that.
df_walleye.isnull().values.any()
# Out:
# False

# %%
# Convert the "official max depth" column to a float
values = []
for depth in df_walleye['Official Max Depth']:
    str_value = str(depth)
    split_str = str_value.split(' ')
    values.append(float(split_str[0]))
df_walleye['Max Depth'] = values
df_walleye.head()
# Out:
#         Lake Name  Size (Acres) Official Max Depth   Latitude  Longitude  \
# 0      Alder Lake           264            30 FEET  46.088099 -89.819586
# 1   Aldridge Lake           142            12 FEET  45.865941 -89.301276
# 2  Alexander Lake           618            36 FEET  45.186975 -89.757128
# 3  Allequash Lake           406            24 FEET  46.036939 -89.628844
# 4       Alma Lake            58            18 FEET  45.909763 -89.428275
#
#   Public Landing  Max Depth
# 0            Yes       30.0
# 1             No       12.0
# 2            Yes       36.0
# 3            Yes       24.0
# 4            Yes       18.0

# %%
# Drop the old column we don't need now
df_walleye = df_walleye.drop('Official Max Depth',1)
df_walleye.head()
# Out:
#         Lake Name  Size (Acres)   Latitude  Longitude Public Landing  \
# 0      Alder Lake           264  46.088099 -89.819586            Yes
# 1   Aldridge Lake           142  45.865941 -89.301276             No
# 2  Alexander Lake           618  45.186975 -89.757128            Yes
# 3  Allequash Lake           406  46.036939 -89.628844            Yes
# 4       Alma Lake            58  45.909763 -89.428275            Yes
#
#    Max Depth
# 0       30.0
# 1       12.0
# 2       36.0
# 3       24.0
# 4       18.0

# %%
# Verify that we have all the right types now
df_walleye.dtypes
# Out:
# Lake Name          object
# Size (Acres)        int64
# Latitude          float64
# Longitude         float64
# Public Landing     object
# Max Depth         float64
# dtype: object

# %% [markdown]
# ## Generate a map of the walleye lakes that have boat landings

# %%
from folium import plugins

# let's start again with a clean copy of the map of Wisconsin
wisc_map = folium.Map(location = [wi_latitude, wi_longitude], zoom_start = 7)

# instantiate a mark cluster object for the incidents in the dataframe
lakes = plugins.MarkerCluster().add_to(wisc_map)

# loop through the dataframe and add each data point to the mark cluster
for lat, lng, label, landing, size, depth in zip(df_walleye.Latitude, df_walleye.Longitude, df_walleye['Lake Name'], df_walleye['Public Landing'], df_walleye['Size (Acres)'], df_walleye['Max Depth']):
    # It must have a the following criteria:
    #    A public boat landing
    #    More than 10 acres in size
    #    Maximum depth must be more than 10 feet
    if landing == 'Yes' and size > 10 and depth > 10:
        popup = folium.Popup(label, parse_html=True)
        folium.Marker(
            location=[lat, lng],
            icon=None,
            popup=popup
        ).add_to(lakes)

# display map
wisc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Visual investigation of the map
#
# We were not surprised to see a cluster of walleye lakes in north central Wisconsin.  Vilas County, in particular, is known as a walleye fishing hot spot.  My husband watches a lot of fishing shows on TV on Saturday mornings and they are frequently fishing in that area.  However, that is quite a distance from Germantown. We might need to consider more of the eastern side of Wisconsin and make the north central area a vacation destination as opposed to a weekend or day trip. However, that decision is premature without more data. So, let's take a look at the state park information.

# %% [markdown]
# ## Get the state park data from the wiki

# %%
# Extract the wiki data that lists the state parks
wiki = requests.get('https://en.wikipedia.org/wiki/List_of_Wisconsin_state_parks')
soup = BeautifulSoup(wiki.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of Wisconsin state parks - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
#   </script>
#   <script>
#    (window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_Wisconsin_state_parks","wgTitle":"List of Wisconsin state parks","wgCurRevisionId":868927473,"wgRevisionId":868927473,"wgArticleId":515671,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Commons category link is on Wikidata","Commons category link is on Wikidata using P373","State parks of Wisconsin","Lists of state parks of the United States","Wisconsin geography-related lists"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"List_of_Wisconsin_state_parks","wgRelevantArticleId":515671,"wgRequestId":"XG8PEgpAME4AABIU6eYAAABQ","wgCSPNonce":false,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{}},"wgStableRevisionId":null,"wgCategoryTreePageCategoryOptions":"{\"mode\":0,\"hideprefix\":20,\"showcount\":true,\"namespaces\":false}","wgWikiEditorEnabledModules":[],"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsShouldSendModuleToUser":true,"wgPopupsConflictsWithNavPopupGadget":false,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en","usePageImages":true,"usePageDescriptions":true},"wgMFIsPageContentModelEditable":true,"wgMFEnableFontChanger":true,"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":false},"wgRelatedArticles":null,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgWMESchemaEditAttemptStepOversample":false,"wgPoweredByHHVM":true,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgWikibaseItemId":"Q257721","wgScoreNoteLanguages":{"arabic":"العربية","catalan":"català","deutsch":"Deutsch","english":"English","espanol":"español","italiano":"italiano","nederlands":"Nederlands","norsk":"norsk","portugues":"português","suomi":"suomi","svenska":"svenska","vlaams":"West-Vlams"},"wgScoreDefaultNoteLanguage":"nederlands","wgCentralAuthMobileDomain":false,"wgCodeMirrorEnabled":true,"wgVisualEditorToolbarScrollOffset":0,"wgVisualEditorUnsupportedEditParams":["undo","undoafter","veswitched"],"wgEditSubmitButtonLabelPublish":true,"oresWikiId":"enwiki","oresBaseUrl":"http://ores.discovery.wmnet:8081/","oresApiVersion":3});mw.loader.state({"ext.gadget.charinsert-styles":"ready","ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready","user":"ready","user.options":"ready","user.tokens":"loading","ext.cite.styles":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.toc.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","ext.3d.styles":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready"});mw.loader.implement("user.tokens@0tffind",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\","patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# });RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.startup","mediawiki.page.ready","jquery.tablesorter","mediawiki.toc","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.eventlogger","ext.uls.init","ext.uls.compactlinks","ext.uls.interface","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"];mw.loader.load(RLPAGEMODULES);});
#   </script>
#   <link href="/w/load.php?debug=false&amp;lang=en&amp;modules=ext.3d.styles%7Cext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.skinning.interface%7Cmediawiki.toc.styles%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <script async="" src="/w/load.php?debug=false&amp;lang=en&amp;modules=startup&amp;only=scripts&amp;skin=vector">
#   </script>
#   <meta content="" name="ResourceLoaderDynamicStyles"/>
#   <link href="/w/load.php?debug=false&amp;lang=en&amp;modules=ext.gadget.charinsert-styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <link href="/w/load.php?debug=false&amp;lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <meta content="MediaWiki 1.33.0-wmf.18" name="generator"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="origin-when-crossorigin" name="referrer"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <meta content="https://upload.wikimedia.org/wikipedia/commons/9/96/Wisconsin_Locator_Map_with_US.PNG" property="og:image"/>
#   <link href="android-app://org.wikipedia/http/en.m.wikipedia.org/wiki/List_of_Wisconsin_state_parks" rel="alternate"/>
#   <link href="/w/index.php?title=List_of_Wisconsin_state_parks&amp;action=edit" rel="alternate" title="Edit this page" type="application/x-wiki"/>
#   <link href="/w/index.php?title=List_of_Wisconsin_state_parks&amp;action=edit" rel="edit" title="Edit this page"/>
#   <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
#   <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
#   <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
#   <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
#   <link href="//creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
#   <link href="https://en.wikipedia.org/wiki/List_of_Wisconsin_state_parks" rel="canonical"/>
#   <link href="//login.wikimedia.org" rel="dns-prefetch"/>
#   <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
#   <!--[if lt IE 9]><script src="/w/load.php?debug=false&amp;lang=en&amp;modules=html5shiv&amp;only=scripts&amp;skin=vector&amp;sync=1"></script><![endif]-->
#  </head>
#  <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-List_of_Wisconsin_state_parks rootpage-List_of_Wisconsin_state_parks skin-vector action-view">
#   <div class="noprint" id="mw-page-base">
#   </div>
#   <div class="noprint" id="mw-head-base">
#   </div>
#   <div class="mw-body" id="content" role="main">
#    <a id="top">
#    </a>
#    <div class="mw-body-content" id="siteNotice">
#     <!-- CentralNotice -->
#    </div>
#    <div class="mw-indicators mw-body-content">
#    </div>
#    <h1 class="firstHeading" id="firstHeading" lang="en">
#     List of Wisconsin state parks
#    </h1>
#    <div class="mw-body-content" id="bodyContent">
#     <div class="noprint" id="siteSub">
#      From Wikipedia, the free encyclopedia
#     </div>
#     <div id="contentSub">
#     </div>
#     <div id="jump-to-nav">
#     </div>
#     <a class="mw-jump-link" href="#mw-head">
#      Jump to navigation
#     </a>
#     <a class="mw-jump-link" href="#p-search">
#      Jump to search
#     </a>
#     <div class="mw-content-ltr" dir="ltr" id="mw-content-text" lang="en">
#      <div class="mw-parser-output">
#       <div class="thumb tright">
#        <div class="thumbinner" style="width:300px;">
#         <div style="position: relative;">
#          <div style="position: absolute; left: 51px; top: 24px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Amnicon_Falls_State_Park" title="Amnicon Falls State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 193px; top: 260px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Aztalan_State_Park" title="Aztalan State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 125px; top: 280px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Belmont_Mound_State_Park" title="Belmont Mound State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 109px; top: 15px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Big_Bay_State_Park" title="Big Bay State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 216px; top: 294px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Big_Foot_Beach_State_Park" title="Big Foot Beach State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 147px; top: 263px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Blue_Mound_State_Park" title="Blue Mound State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 152px; top: 292px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Browntown-Cadiz_Springs_State_Recreation_Area" title="Browntown-Cadiz Springs State Recreation Area">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 88px; top: 120px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Brunet_Island_State_Park" title="Brunet Island State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 140px; top: 201px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Buckhorn_State_Park" title="Buckhorn State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 173px; top: 262px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Capital_Springs_State_Park_and_Recreation_Area" title="Capital Springs State Park and Recreation Area">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 73px; top: 115px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Chippewa_Moraine_State_Recreation_Area" title="Chippewa Moraine State Recreation Area">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 238px; top: 140px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Copper_Culture_State_Park" title="Copper Culture State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 110px; top: 42px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Copper_Falls_State_Park" title="Copper Falls State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 154px; top: 120px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Council_Grounds_State_Park" title="Council Grounds State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 155px; top: 235px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Devil%27s_Lake_State_Park_(Wisconsin)" title="Devil's Lake State Park (Wisconsin)">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 246px; top: 202px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Fischer_Creek_State_Recreation_Area" title="Fischer Creek State Recreation Area">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 135px; top: 263px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Governor_Dodge_State_Park" title="Governor Dodge State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 168px; top: 257px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Governor_Nelson_State_Park" title="Governor Nelson State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 232px; top: 110px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Governor_Thompson_State_Park" title="Governor Thompson State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 243px; top: 230px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Harrington_Beach_State_Park" title="Harrington Beach State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 179px; top: 175px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Hartman_Creek_State_Park" title="Hartman Creek State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 234px; top: 167px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Heritage_Hill_State_Historical_Park" title="Heritage Hill State Historical Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 222px; top: 188px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/High_Cliff_State_Park" title="High Cliff State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 55px; top: 139px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Hoffman_Hills_State_Recreation_Area" title="Hoffman Hills State Recreation Area">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 17px; top: 108px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Interstate_Park" title="Interstate Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 12px; top: 145px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Kinnickinnic_State_Park" title="Kinnickinnic State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 246px; top: 220px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Kohler-Andrae_State_Park" title="Kohler-Andrae State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 176px; top: 267px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Lake_Kegonsa_State_Park" title="Lake Kegonsa State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 81px; top: 132px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Lake_Wissota_State_Park" title="Lake Wissota State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 240px; top: 262px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Lakeshore_State_Park" title="Lakeshore State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 241px; top: 85px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Menominee_River_State_Park_and_Recreation_Area" title="Menominee River State Park and Recreation Area">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 59px; top: 188px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Merrick_State_Park" title="Merrick State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 125px; top: 200px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Mill_Bluff_State_Park" title="Mill Bluff State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 148px; top: 227px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Mirror_Lake_State_Park" title="Mirror Lake State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 145px; top: 245px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Natural_Bridge_State_Park_(Wisconsin)" title="Natural Bridge State Park (Wisconsin)">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 95px; top: 284px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Nelson_Dewey_State_Park" title="Nelson Dewey State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 158px; top: 280px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/New_Glarus_Woods_State_Park" title="New Glarus Woods State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 280px; top: 115px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Newport_State_Park" title="Newport State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 41px; top: 29px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Pattison_State_Park" title="Pattison State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 275px; top: 118px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Peninsula_State_Park" title="Peninsula State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 74px; top: 197px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Perrot_State_Park" title="Perrot State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 261px; top: 142px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Potawatomi_State_Park" title="Potawatomi State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 155px; top: 140px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Rib_Mountain_State_Park" title="Rib Mountain State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 230px; top: 290px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Richard_Bong_State_Recreation_Area" title="Richard Bong State Recreation Area">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 150px; top: 196px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Roche-a-Cri_State_Park" title="Roche-a-Cri State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 290px; top: 105px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Rock_Island_State_Park_(Wisconsin)" title="Rock Island State Park (Wisconsin)">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 149px; top: 221px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Rocky_Arbor_State_Park" title="Rocky Arbor State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 25px; top: 92px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Straight_Lake_State_Park" title="Straight Lake State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 138px; top: 253px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Tower_Hill_State_Park" title="Tower Hill State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 271px; top: 137px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Whitefish_Dunes_State_Park" title="Whitefish Dunes State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 115px; top: 220px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Wildcat_Mountain_State_Park" title="Wildcat Mountain State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 15px; top: 132px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Willow_River_State_Park" title="Willow River State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 88px; top: 266px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Wyalusing_State_Park" title="Wyalusing State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <div style="position: absolute; left: 142px; top: 280px; padding: 0;">
#           <span style="position:relative; overflow:hidden; width:5px; height:5px; z-index:2;">
#            <a href="/wiki/Yellowstone_Lake_State_Park" title="Yellowstone Lake State Park">
#             <img alt="Green pog.svg" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/5px-Green_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/8px-Green_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Green_pog.svg/10px-Green_pog.svg.png 2x" width="5"/>
#            </a>
#           </span>
#          </div>
#          <a class="image" href="/wiki/File:Wisconsin_Locator_Map_with_US.PNG">
# ...
#         Log in
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div id="left-navigation">
#      <div aria-labelledby="p-namespaces-label" class="vectorTabs" id="p-namespaces" role="navigation">
#       <h3 id="p-namespaces-label">
#        Namespaces
#       </h3>
#       <ul>
#        <li class="selected" id="ca-nstab-main">
#         <span>
#          <a accesskey="c" href="/wiki/List_of_Wisconsin_state_parks" title="View the content page [c]">
#           Article
#          </a>
#         </span>
#        </li>
#        <li id="ca-talk">
#         <span>
#          <a accesskey="t" href="/wiki/Talk:List_of_Wisconsin_state_parks" rel="discussion" title="Discussion about the content page [t]">
#           Talk
#          </a>
#         </span>
#        </li>
#       </ul>
#      </div>
#      <div aria-labelledby="p-variants-label" class="vectorMenu emptyPortlet" id="p-variants" role="navigation">
#       <input aria-labelledby="p-variants-label" class="vectorMenuCheckbox" type="checkbox"/>
#       <h3 id="p-variants-label">
#        <span>
#         Variants
#        </span>
#       </h3>
#       <ul class="menu">
#       </ul>
#      </div>
#     </div>
#     <div id="right-navigation">
#      <div aria-labelledby="p-views-label" class="vectorTabs" id="p-views" role="navigation">
#       <h3 id="p-views-label">
#        Views
#       </h3>
#       <ul>
#        <li class="collapsible selected" id="ca-view">
#         <span>
#          <a href="/wiki/List_of_Wisconsin_state_parks">
#           Read
#          </a>
#         </span>
#        </li>
#        <li class="collapsible" id="ca-edit">
#         <span>
#          <a accesskey="e" href="/w/index.php?title=List_of_Wisconsin_state_parks&amp;action=edit" title="Edit this page [e]">
#           Edit
#          </a>
#         </span>
#        </li>
#        <li class="collapsible" id="ca-history">
#         <span>
#          <a accesskey="h" href="/w/index.php?title=List_of_Wisconsin_state_parks&amp;action=history" title="Past revisions of this page [h]">
#           View history
#          </a>
#         </span>
#        </li>
#       </ul>
#      </div>
#      <div aria-labelledby="p-cactions-label" class="vectorMenu emptyPortlet" id="p-cactions" role="navigation">
#       <input aria-labelledby="p-cactions-label" class="vectorMenuCheckbox" type="checkbox"/>
#       <h3 id="p-cactions-label">
#        <span>
#         More
#        </span>
#       </h3>
#       <ul class="menu">
#       </ul>
#      </div>
#      <div id="p-search" role="search">
#       <h3>
#        <label for="searchInput">
#         Search
#        </label>
#       </h3>
#       <form action="/w/index.php" id="searchform">
#        <div id="simpleSearch">
#         <input accesskey="f" id="searchInput" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" type="search"/>
#         <input name="title" type="hidden" value="Special:Search"/>
#         <input class="searchButton mw-fallbackSearchButton" id="mw-searchButton" name="fulltext" title="Search Wikipedia for this text" type="submit" value="Search"/>
#         <input class="searchButton" id="searchButton" name="go" title="Go to a page with this exact name if it exists" type="submit" value="Go"/>
#        </div>
#       </form>
#      </div>
#     </div>
#    </div>
#    <div id="mw-panel">
#     <div id="p-logo" role="banner">
#      <a class="mw-wiki-logo" href="/wiki/Main_Page" title="Visit the main page">
#      </a>
#     </div>
#     <div aria-labelledby="p-navigation-label" class="portal" id="p-navigation" role="navigation">
#      <h3 id="p-navigation-label">
#       Navigation
#      </h3>
#      <div class="body">
#       <ul>
#        <li id="n-mainpage-description">
#         <a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]">
#          Main page
#         </a>
#        </li>
#        <li id="n-contents">
#         <a href="/wiki/Portal:Contents" title="Guides to browsing Wikipedia">
#          Contents
#         </a>
#        </li>
#        <li id="n-featuredcontent">
#         <a href="/wiki/Portal:Featured_content" title="Featured content – the best of Wikipedia">
#          Featured content
#         </a>
#        </li>
#        <li id="n-currentevents">
#         <a href="/wiki/Portal:Current_events" title="Find background information on current events">
#          Current events
#         </a>
#        </li>
#        <li id="n-randompage">
#         <a accesskey="x" href="/wiki/Special:Random" title="Load a random article [x]">
#          Random article
#         </a>
#        </li>
#        <li id="n-sitesupport">
#         <a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us">
#          Donate to Wikipedia
#         </a>
#        </li>
#        <li id="n-shoplink">
#         <a href="//shop.wikimedia.org" title="Visit the Wikipedia store">
#          Wikipedia store
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div aria-labelledby="p-interaction-label" class="portal" id="p-interaction" role="navigation">
#      <h3 id="p-interaction-label">
#       Interaction
#      </h3>
#      <div class="body">
#       <ul>
#        <li id="n-help">
#         <a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">
#          Help
#         </a>
#        </li>
#        <li id="n-aboutsite">
#         <a href="/wiki/Wikipedia:About" title="Find out about Wikipedia">
#          About Wikipedia
#         </a>
#        </li>
#        <li id="n-portal">
#         <a href="/wiki/Wikipedia:Community_portal" title="About the project, what you can do, where to find things">
#          Community portal
#         </a>
#        </li>
#        <li id="n-recentchanges">
#         <a accesskey="r" href="/wiki/Special:RecentChanges" title="A list of recent changes in the wiki [r]">
#          Recent changes
#         </a>
#        </li>
#        <li id="n-contactpage">
#         <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">
#          Contact page
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div aria-labelledby="p-tb-label" class="portal" id="p-tb" role="navigation">
#      <h3 id="p-tb-label">
#       Tools
#      </h3>
#      <div class="body">
#       <ul>
#        <li id="t-whatlinkshere">
#         <a accesskey="j" href="/wiki/Special:WhatLinksHere/List_of_Wisconsin_state_parks" title="List of all English Wikipedia pages containing links to this page [j]">
#          What links here
#         </a>
#        </li>
#        <li id="t-recentchangeslinked">
#         <a accesskey="k" href="/wiki/Special:RecentChangesLinked/List_of_Wisconsin_state_parks" rel="nofollow" title="Recent changes in pages linked from this page [k]">
#          Related changes
#         </a>
#        </li>
#        <li id="t-upload">
#         <a accesskey="u" href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]">
#          Upload file
#         </a>
#        </li>
#        <li id="t-specialpages">
#         <a accesskey="q" href="/wiki/Special:SpecialPages" title="A list of all special pages [q]">
#          Special pages
#         </a>
#        </li>
#        <li id="t-permalink">
#         <a href="/w/index.php?title=List_of_Wisconsin_state_parks&amp;oldid=868927473" title="Permanent link to this revision of the page">
#          Permanent link
#         </a>
#        </li>
#        <li id="t-info">
#         <a href="/w/index.php?title=List_of_Wisconsin_state_parks&amp;action=info" title="More information about this page">
#          Page information
#         </a>
#        </li>
#        <li id="t-wikibase">
#         <a accesskey="g" href="https://www.wikidata.org/wiki/Special:EntityPage/Q257721" title="Link to connected data repository item [g]">
#          Wikidata item
#         </a>
#        </li>
#        <li id="t-cite">
#         <a href="/w/index.php?title=Special:CiteThisPage&amp;page=List_of_Wisconsin_state_parks&amp;id=868927473" title="Information on how to cite this page">
#          Cite this page
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div aria-labelledby="p-coll-print_export-label" class="portal" id="p-coll-print_export" role="navigation">
#      <h3 id="p-coll-print_export-label">
#       Print/export
#      </h3>
#      <div class="body">
#       <ul>
#        <li id="coll-create_a_book">
#         <a href="/w/index.php?title=Special:Book&amp;bookcmd=book_creator&amp;referer=List+of+Wisconsin+state+parks">
#          Create a book
#         </a>
#        </li>
#        <li id="coll-download-as-rdf2latex">
#         <a href="/w/index.php?title=Special:ElectronPdf&amp;page=List+of+Wisconsin+state+parks&amp;action=show-download-screen">
#          Download as PDF
#         </a>
#        </li>
#        <li id="t-print">
#         <a accesskey="p" href="/w/index.php?title=List_of_Wisconsin_state_parks&amp;printable=yes" title="Printable version of this page [p]">
#          Printable version
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div aria-labelledby="p-wikibase-otherprojects-label" class="portal" id="p-wikibase-otherprojects" role="navigation">
#      <h3 id="p-wikibase-otherprojects-label">
#       In other projects
#      </h3>
#      <div class="body">
#       <ul>
#        <li class="wb-otherproject-link wb-otherproject-commons">
#         <a href="https://commons.wikimedia.org/wiki/Category:State_parks_of_Wisconsin" hreflang="en">
#          Wikimedia Commons
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div aria-labelledby="p-lang-label" class="portal" id="p-lang" role="navigation">
#      <h3 id="p-lang-label">
#       Languages
#      </h3>
#      <div class="body">
#       <ul>
#        <li class="interlanguage-link interwiki-bar">
#         <a class="interlanguage-link-target" href="https://bar.wikipedia.org/wiki/State_Parks_in_Wisconsin" hreflang="bar" lang="bar" title="State Parks in Wisconsin – Bavarian">
#          Boarisch
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-de">
#         <a class="interlanguage-link-target" href="https://de.wikipedia.org/wiki/State_Parks_in_Wisconsin" hreflang="de" lang="de" title="State Parks in Wisconsin – German">
#          Deutsch
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-fr">
#         <a class="interlanguage-link-target" href="https://fr.wikipedia.org/wiki/Liste_des_parcs_d%27%C3%89tat_du_Wisconsin" hreflang="fr" lang="fr" title="Liste des parcs d'État du Wisconsin – French">
#          Français
#         </a>
#        </li>
#       </ul>
#       <div class="after-portlet after-portlet-lang">
#        <span class="wb-langlinks-edit wb-langlinks-link">
#         <a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q257721#sitelinks-wikipedia" title="Edit interlanguage links">
#          Edit links
#         </a>
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="footer" role="contentinfo">
#    <ul id="footer-info">
#     <li id="footer-info-lastmod">
#      This page was last edited on 15 November 2018, at 08:28
#      <span class="anonymous-show">
#       (UTC)
#      </span>
#      .
#     </li>
#     <li id="footer-info-copyright">
#      Text is available under the
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License" rel="license">
#       Creative Commons Attribution-ShareAlike License
#      </a>
#      <a href="//creativecommons.org/licenses/by-sa/3.0/" rel="license" style="display:none;">
#      </a>
#      ;
# additional terms may apply.  By using this site, you agree to the
#      <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">
#       Terms of Use
#      </a>
#      and
#      <a href="//foundation.wikimedia.org/wiki/Privacy_policy">
#       Privacy Policy
#      </a>
#      . Wikipedia® is a registered trademark of the
#      <a href="//www.wikimediafoundation.org/">
#       Wikimedia Foundation, Inc.
#      </a>
#      , a non-profit organization.
#     </li>
#    </ul>
#    <ul id="footer-places">
#     <li id="footer-places-privacy">
#      <a class="extiw" href="https://foundation.wikimedia.org/wiki/Privacy_policy" title="wmf:Privacy policy">
#       Privacy policy
#      </a>
#     </li>
#     <li id="footer-places-about">
#      <a href="/wiki/Wikipedia:About" title="Wikipedia:About">
#       About Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-disclaimer">
#      <a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">
#       Disclaimers
#      </a>
#     </li>
#     <li id="footer-places-contact">
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">
#       Contact Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-developers">
#      <a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">
#       Developers
#      </a>
#     </li>
#     <li id="footer-places-cookiestatement">
#      <a href="https://foundation.wikimedia.org/wiki/Cookie_statement">
#       Cookie statement
#      </a>
#     </li>
#     <li id="footer-places-mobileview">
#      <a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=List_of_Wisconsin_state_parks&amp;mobileaction=toggle_view_mobile">
#       Mobile view
#      </a>
#     </li>
#    </ul>
#    <ul class="noprint" id="footer-icons">
#     <li id="footer-copyrightico">
#      <a href="https://wikimediafoundation.org/">
#       <img alt="Wikimedia Foundation" height="31" src="/static/images/wikimedia-button.png" srcset="/static/images/wikimedia-button-1.5x.png 1.5x, /static/images/wikimedia-button-2x.png 2x" width="88"/>
#      </a>
#     </li>
#     <li id="footer-poweredbyico">
#      <a href="//www.mediawiki.org/">
#       <img alt="Powered by MediaWiki" height="31" src="/static/images/poweredby_mediawiki_88x31.png" srcset="/static/images/poweredby_mediawiki_132x47.png 1.5x, /static/images/poweredby_mediawiki_176x62.png 2x" width="88"/>
#      </a>
#     </li>
#    </ul>
#    <div style="clear: both;">
#    </div>
#   </div>
#   <script>
#    (window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"1.088","walltime":"1.241","ppvisitednodes":{"value":4508,"limit":1000000},"ppgeneratednodes":{"value":0,"limit":1500000},"postexpandincludesize":{"value":225543,"limit":2097152},"templateargumentsize":{"value":8184,"limit":2097152},"expansiondepth":{"value":13,"limit":40},"expensivefunctioncount":{"value":0,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":177112,"limit":5000000},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00%  828.330      1 -total"," 59.31%  491.243      1 Template:Reflist"," 38.19%  316.341     60 Template:Cite_web"," 15.90%  131.676     86 Template:Convert","  9.97%   82.601      1 Template:Cite_news","  7.97%   66.054      1 Template:Commons_category","  6.91%   57.209      5 Template:Navbox","  5.51%   45.677      1 Template:Wisconsin","  4.93%   40.852      1 Template:US_state_navigation_box","  1.90%   15.773      1 Template:Protected_areas_of_Wisconsin"]},"scribunto":{"limitreport-timeusage":{"value":"0.485","limit":"10.000"},"limitreport-memusage":{"value":6209711,"limit":52428800}},"cachereport":{"origin":"mw1243","timestamp":"20190221205027","ttl":2073600,"transientcontent":false}}});});
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https:\/\/schema.org","@type":"Article","name":"List of Wisconsin state parks","url":"https:\/\/en.wikipedia.org\/wiki\/List_of_Wisconsin_state_parks","sameAs":"http:\/\/www.wikidata.org\/entity\/Q257721","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q257721","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2004-03-09T18:07:03Z","dateModified":"2018-11-15T08:28:11Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/9\/96\/Wisconsin_Locator_Map_with_US.PNG","headline":"Wikimedia list article"}
#   </script>
#   <script>
#    (window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":1375,"wgHostname":"mw1243"});});
#   </script>
#  </body>
# </html>

# %%
# Create an empty dataframe and append the state parks into it
columns = ['Park Name', 'Latitude', 'Longitude']
df_parks = pd.DataFrame(columns=columns)

# Get all the parks from the html into a dataframe
tables = soup.find_all("div",class_="thumbinner")
for table in tables:
    parks = table.find_all('a',title=True)
    for p in parks:
        words = p['title'].split()


        
        # By requiring the last word to be "Park" I am eliminating things like "Recreation Areas"
        if words[-1] == 'Park':
            p = p['title']
            address = p + ', Wisconsin, United States'
            
            geolocator = Nominatim(user_agent="wi_explorer")
            location = geolocator.geocode(address)
            
            df_parks = df_parks.append({"Park Name": p, 
                                        "Latitude": location.latitude, 
                                        "Longitude": location.longitude},
                                        ignore_index=True)
df_parks
# Out:
#                               Park Name   Latitude  Longitude
# 0              Amnicon Falls State Park  46.614722 -91.898624
# 1                    Aztalan State Park  43.066505 -88.860419
# 2              Belmont Mound State Park  42.770246 -90.349897
# 3                    Big Bay State Park  46.807026 -90.692332
# 4             Big Foot Beach State Park  42.569318 -88.426371
# 5                 Blue Mound State Park  43.029826 -89.847391
# 6              Brunet Island State Park  45.180821 -91.161065
# 7                   Buckhorn State Park  43.942055 -90.007676
# 8             Copper Culture State Park  44.886931 -87.899535
# 9               Copper Falls State Park  46.370326 -90.645562
# 10           Council Grounds State Park  45.185459 -89.742512
# 11            Governor Dodge State Park  43.026921 -90.105349
# 12           Governor Nelson State Park  43.134135 -89.436810
# 13         Governor Thompson State Park  45.336491 -88.245653
# 14          Harrington Beach State Park  43.491289 -87.804106
# 15             Hartman Creek State Park  44.324197 -89.212009
# 16  Heritage Hill State Historical Park  44.474396 -88.032636
# 17                High Cliff State Park  44.154254 -88.292276
# 18                      Interstate Park  45.406303 -92.626047
# 19              Kinnickinnic State Park  44.829435 -92.752313
# 20             Kohler-Andrae State Park  43.668004 -87.721056
# 21              Lake Kegonsa State Park  42.976421 -89.232629
# 22              Lake Wissota State Park  44.973251 -91.299298
# 23                 Lakeshore State Park  43.032696 -87.895434
# 24                   Merrick State Park  44.153312 -91.753092
# 25                Mill Bluff State Park  43.952694 -90.304460
# 26               Mirror Lake State Park  43.563752 -89.818114
# 27              Nelson Dewey State Park  42.736295 -91.024374
# 28          New Glarus Woods State Park  42.786896 -89.631967
# 29                   Newport State Park  45.243152 -86.986269
# 30                  Pattison State Park  46.536727 -92.118059
# 31                 Peninsula State Park  45.150029 -87.220111
# 32                    Perrot State Park  44.019926 -91.473018
# 33                Potawatomi State Park  44.864210 -87.414364
# 34              Rib Mountain State Park  44.919860 -89.696359
# 35               Roche-a-Cri State Park  44.003183 -89.819367
# 36               Rocky Arbor State Park  43.642654 -89.807000
# 37             Straight Lake State Park  45.608555 -92.415112
# 38                Tower Hill State Park  43.150388 -90.041852
# 39           Whitefish Dunes State Park  44.923273 -87.199577
# 40          Wildcat Mountain State Park  43.698611 -90.559394
# 41              Willow River State Park  45.019065 -92.695590
# 42                 Wyalusing State Park  42.973929 -91.121797
# 43          Yellowstone Lake State Park  42.771326 -89.963643

# %%
# Map the state parks on their own map. For fun, make them use a tree icon.
park_map = folium.Map(location = [wi_latitude, wi_longitude], zoom_start = 7)

for lat, lng, park in zip(df_parks['Latitude'], df_parks['Longitude'], df_parks['Park Name']):
    label = folium.Popup(park)
    folium.Marker([lat, lng],
              popup=label,
              icon=folium.Icon(color='green',icon='tree',prefix='fa')
              ).add_to(park_map)

park_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Combine the maps of walleye lakes and state parks and add a purple circle to represent Germantown

# %%
for lat, lng, park in zip(df_parks['Latitude'], df_parks['Longitude'], df_parks['Park Name']):
    label = folium.Popup(park)
for lat, lng, park in zip(df_parks['Latitude'], df_parks['Longitude'], df_parks['Park Name']):
    label = folium.Popup(park)
    folium.Marker([lat, lng],
              popup=label,
              icon=folium.Icon(color='green',icon='tree',prefix='fa')
              ).add_to(wisc_map)
    
# add a purple circle marker to represent the Germanton
address = 'Germantown, Wisconsin'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
folium.features.CircleMarker(
    [location.latitude, location.longitude],
    radius=5,
    color='purple',
    popup='Germantown',
    fill = True,
    fill_color = 'purple',
    fill_opacity = 0.6
).add_to(wisc_map)

wisc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Visual investigation of the combined map
#
# There were several surprises when looking at the combined map.
#     1. In the north central part of Wisconsin which is famous for walleye fishing, there aren't any state parks at all!  We were very surprised by this. However, there are a lot of forests. As a future enhancement to this project, I need to look at the state and national forests to see if there is camping and hiking available there.
#     2. There are a lot of state parks in the central and south central region that we hadn't noticed before.
#     3. There aren't very many state parks along Lake Michigan. We would have thought that would be a prime location for them.
#     4. Waupaca might be a candidate. It's close to a lot of the fishing and it's only 97 minutes from Germantown and it's on a main highway. Let's see what kind of Italian restaurants it has for a smaller town.

# %% [markdown]
# ## Use the Foursquare API to get venues for our chosen location

# %%
# Input my credentials
CLIENT_ID = '2YXOIKQTLPEEBMTAKN1PXAHCY2N4L23U4EXKWJEGLQLV1R02' # your Foursquare ID
CLIENT_SECRET = 'RI1RD132ULSAONFM2EAZTI0H5OBNG0H441R5J1IFN2UBZCRO' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 2YXOIKQTLPEEBMTAKN1PXAHCY2N4L23U4EXKWJEGLQLV1R02
# CLIENT_SECRET:RI1RD132ULSAONFM2EAZTI0H5OBNG0H441R5J1IFN2UBZCRO

# %%
# Get the latitude and longitude for Waupaca, Wisconsin
address = 'Waupaca, Wisconsin'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
gt_latitude = location.latitude
gt_longitude = location.longitude
print(gt_latitude, gt_longitude)
# Out:
# 44.4927889 -88.9650419

# %%
# Construct the URL for the Foursquare API call.
search_query = 'Italian'

# The radius is in meters. We want it to be within 10 miles so using 1600 meters to a mile (estimate),
# the number of meters is 16000
radius = 16000
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, gt_latitude, gt_longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=2YXOIKQTLPEEBMTAKN1PXAHCY2N4L23U4EXKWJEGLQLV1R02&client_secret=RI1RD132ULSAONFM2EAZTI0H5OBNG0H441R5J1IFN2UBZCRO&ll=44.4927889,-88.9650419&v=20180604&query=Italian&radius=16000&limit=100'

# %%
# Send the get request and examine the results
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c7059c86a60714c850523b6'},
#  'response': {'venues': []}}

# %% [markdown]
# ## Oh my goodness! There aren't any close!
#
# So, that was eye-opening! There aren't any Italian restaurants within 10 miles of Waupaca. Let's pick a larger city and expand the area to 50 miles. Let's try Appleton.

# %%
# Get the latitude and longitude for Appleton, Wisconsin
address = 'Appleton, Wisconsin'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
gt_latitude = location.latitude
gt_longitude = location.longitude
print(gt_latitude, gt_longitude)
# Out:
# 44.2611337 -88.4067604

# %%
# Construct the URL for the Foursquare API call.
search_query = 'Italian'

# The radius is in meters. We want it to be within 50 miles so using 1600 meters to a mile (estimate),
# the number of meters is 80000
radius = 80000
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, gt_latitude, gt_longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=2YXOIKQTLPEEBMTAKN1PXAHCY2N4L23U4EXKWJEGLQLV1R02&client_secret=RI1RD132ULSAONFM2EAZTI0H5OBNG0H441R5J1IFN2UBZCRO&ll=44.2611337,-88.4067604&v=20180604&query=Italian&radius=80000&limit=100'

# %%
# Send the get request and examine the results
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c7059cd4c1f67635226aaf1'},
#  'response': {'venues': [{'id': '4b2aeb8df964a5201ab224e3',
#     'name': "Carmella's an Italian Bistro",
#     'location': {'address': '724 N Casaloma Dr',
#      'lat': 44.2699603455633,
#      'lng': -88.47485930580342,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.2699603455633,
#        'lng': -88.47485930580342}],
#      'distance': 5516,
#      'postalCode': '54913-8549',
#      'cc': 'US',
#      'city': 'Appleton',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['724 N Casaloma Dr',
#       'Appleton, WI 54913-8549',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '4b6dc745f964a520f68e2ce3',
#     'name': "Victoria's",
#     'location': {'address': '503 W College Ave',
#      'lat': 44.26179255420541,
#      'lng': -88.41223429886749,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.26179255420541,
#        'lng': -88.41223429886749}],
#      'distance': 442,
#      'postalCode': '54911',
#      'cc': 'US',
#      'city': 'Appleton',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['503 W College Ave',
#       'Appleton, WI 54911',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '4ec8545661af9e1430d1a63a',
#     'name': 'Italian stallion villa',
#     'location': {'lat': 44.296810150146484,
#      'lng': -88.38290405273438,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.296810150146484,
#        'lng': -88.38290405273438}],
#      'distance': 4403,
#      'postalCode': '54911',
#      'cc': 'US',
#      'city': 'Appleton',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['Appleton, WI 54911', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11e941735',
#       'name': 'Cocktail Bar',
#       'pluralName': 'Cocktail Bars',
#       'shortName': 'Cocktail',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '4fad6d83e4b017dfa581928b',
#     'name': "Scarletini's Italian Cooking",
#     'location': {'lat': 44.28387281748089,
#      'lng': -88.39361519758948,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.28387281748089,
#        'lng': -88.39361519758948}],
#      'distance': 2739,
#      'postalCode': '54911',
#      'cc': 'US',
#      'city': 'Appleton',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['Appleton, WI 54911', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '4b58fd59f964a520297728e3',
#     'name': 'Olive Garden',
#     'location': {'address': '1275 N Casaloma Dr',
#      'lat': 44.27241936600967,
#      'lng': -88.47691766389673,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.27241936600967,
#        'lng': -88.47691766389673}],
#      'distance': 5731,
#      'postalCode': '54913',
#      'cc': 'US',
#      'city': 'Appleton',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['1275 N Casaloma Dr',
#       'Appleton, WI 54913',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '4fcff475e4b01b683f30c149',
#     'name': "Luigi's Italian Restaurant",
#     'location': {'lat': 44.222312927246094,
#      'lng': -88.32283782958984,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.222312927246094,
#        'lng': -88.32283782958984}],
#      'distance': 7966,
#      'postalCode': '54915',
#      'cc': 'US',
#      'city': 'Appleton',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['Appleton, WI 54915', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '4f32792a19836c91c7db3ccd',
#     'name': 'Luna Italian Restaurant and Mkt',
#     'location': {'address': '124 W Wisconsin Ave',
#      'lat': 44.186993,
#      'lng': -88.463031,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.186993,
#        'lng': -88.463031}],
#      'distance': 9395,
#      'postalCode': '54956',
#      'cc': 'US',
#      'city': 'Neenah',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['124 W Wisconsin Ave',
#       'Neenah, WI 54956',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '4c4a0c425609c9b6804f1f8f',
#     'name': "Rozzi's Italian Deli &  Market",
#     'location': {'address': '2450 Velp Ave',
#      'lat': 44.56349730491638,
#      'lng': -88.07315014,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.56349730491638,
#        'lng': -88.07315014}],
#      'distance': 42855,
#      'postalCode': '54303',
#      'cc': 'US',
#      'city': 'Howard',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['2450 Velp Ave',
#       'Howard, WI 54303',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'shortName': 'Deli / Bodega',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '4bad37a0f964a520613a3be3',
#     'name': "Gino's Italian",
#     'location': {'address': '584 W Johnson St.',
#      'lat': 43.784086159168375,
#      'lng': -88.46914163868878,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.784086159168375,
#        'lng': -88.46914163868878}],
#      'distance': 53338,
#      'postalCode': '54935',
#      'cc': 'US',
#      'city': 'Fond du Lac',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['584 W Johnson St.',
#       'Fond du Lac, WI 54935',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '371012324'},
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '4b74b34ff964a52036ed2de3',
#     'name': 'Grazies Italian Grill',
#     'location': {'address': '2851 S Oneida St',
#      'lat': 44.47153254798962,
#      'lng': -88.07473349048001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.47153254798962,
#        'lng': -88.07473349048001}],
#      'distance': 35308,
#      'postalCode': '54304',
#      'cc': 'US',
#      'city': 'Green Bay',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['2851 S Oneida St',
#       'Green Bay, WI 54304',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '890514',
#      'url': 'https://www.grubhub.com/restaurant/grazies-italian-grill-2851-s-oneida-st-green-bay/890514?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=890514',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '55055647'},
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '4b8bfd90f964a520ceb632e3',
#     'name': "Sammy's Pizza & Italian Restaurant",
#     'location': {'address': '2161 S Oneida St',
#      'lat': 44.4933218,
#      'lng': -88.0619437,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.4933218,
#        'lng': -88.0619437}],
#      'distance': 37692,
#      'postalCode': '54304',
#      'cc': 'US',
#      'city': 'Green Bay',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['2161 S Oneida St',
#       'Green Bay, WI 54304',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '4c4cb2ae50710f476a5f8132',
#     'name': "Benvenuto's",
#     'location': {'address': '300 S Koeller St',
#      'crossStreet': 'at Witzel Ave',
#      'lat': 44.015244,
#      'lng': -88.581741,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.015244,
#        'lng': -88.581741}],
#      'distance': 30735,
#      'postalCode': '54902',
#      'cc': 'US',
#      'city': 'Oshkosh',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['300 S Koeller St (at Witzel Ave)',
#       'Oshkosh, WI 54902',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '507625d5e4b05275689a98ee',
#     'name': 'Italian Room DLC',
#     'location': {'address': '1415 E Walnut St',
#      'lat': 44.50710272364985,
#      'lng': -87.99297364231487,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.50710272364985,
#        'lng': -87.99297364231487}],
#      'distance': 42817,
#      'postalCode': '54301',
#      'cc': 'US',
#      'city': 'Green Bay',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['1415 E Walnut St',
#       'Green Bay, WI 54301',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '4bbe29d30ec69c7430ef5559',
#     'name': 'Grazies Italian Grill',
#     'location': {'lat': 44.49487526280353,
#      'lng': -88.12283010966345,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.49487526280353,
#        'lng': -88.12283010966345}],
#      'distance': 34458,
#      'cc': 'US',
#      'state': 'Wisconsin',
#      'country': 'United States',
#      'formattedAddress': ['Wisconsin', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '4f3233b219836c91c7c02fb2',
#     'name': "Jersey's Sports Bar and Italian Grill",
#     'location': {'address': '614 George St',
#      'lat': 44.4489,
#      'lng': -88.05785,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.4489,
#        'lng': -88.05785}],
#      'distance': 34758,
#      'postalCode': '54115',
#      'cc': 'US',
#      'city': 'Depere',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['614 George St',
#       'Depere, WI 54115',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '52ae2d4411d21d133f97578f',
#     'name': 'Italian Rome',
#     'location': {'lat': 44.498756408691406,
#      'lng': -87.98240661621094,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.498756408691406,
#        'lng': -87.98240661621094}],
#      'distance': 42890,
#      'cc': 'US',
#      'city': 'Green Bay',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['Green Bay, WI', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'shortName': 'Entertainment',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '4b97f845f964a520172335e3',
#     'name': 'Olive Garden',
#     'location': {'address': '2819 S Oneida St',
#      'lat': 44.4740502548479,
#      'lng': -88.07427216570832,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.4740502548479,
#        'lng': -88.07427216570832}],
#      'distance': 35522,
#      'postalCode': '54304',
#      'cc': 'US',
#      'city': 'Green Bay',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['2819 S Oneida St',
#       'Green Bay, WI 54304',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '4e7e6c02f5b99ba2ebf64e77',
#     'name': 'Bilottis Pizza & Italian Garden',
#     'location': {'lat': 44.42961674262697,
#      'lng': -88.0251092021685,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.42961674262697,
#        'lng': -88.0251092021685}],
#      'distance': 35705,
#      'postalCode': '54115',
#      'cc': 'US',
#      'city': 'Depere',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['Depere, WI 54115', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '4f32a1db19836c91c7eaaabb',
#     'name': "Savvy's Italian Cuisine",
#     'location': {'address': '1015 W Mason St',
#      'lat': 44.52417,
#      'lng': -88.09519,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.52417,
#        'lng': -88.09519}],
#      'distance': 38361,
#      'postalCode': '54303',
#      'cc': 'US',
#      'city': 'Green Bay',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['1015 W Mason St',
#       'Green Bay, WI 54303',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '4bb779cd3db7b7135d01209a',
#     'name': "Luigi's Italian Bistro",
#     'location': {'address': '2733 Manitowoc Rd Ste 5',
#      'lat': 44.46470096289037,
#      'lng': -87.94569132088888,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.46470096289037,
#        'lng': -87.94569132088888}],
#      'distance': 43127,
#      'postalCode': '54311',
#      'cc': 'US',
#      'city': 'Green Bay',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['2733 Manitowoc Rd Ste 5',
#       'Green Bay, WI 54311',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '4f44d87a19836ed00196ef4a',
#     'name': 'Italian Palace and Grill',
#     'location': {'address': '1216 W Fond du Lac St',
#      'lat': 43.855568,
#      'lng': -88.864246,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.855568,
#        'lng': -88.864246}],
#      'distance': 58117,
#      'postalCode': '54971',
#      'cc': 'US',
#      'city': 'Ripon',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['1216 W Fond du Lac St',
#       'Ripon, WI 54971',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '5926a29ab546182970906399',
#     'name': "Gino's Italian Restaurant",
#     'location': {'address': '584 W Johnson St',
#      'lat': 43.78382,
#      'lng': -88.46931,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.78382,
#        'lng': -88.46931}],
#      'distance': 53369,
#      'postalCode': '54935',
#      'cc': 'US',
#      'city': 'Fond du Lac',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['584 W Johnson St',
#       'Fond du Lac, WI 54935',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '4bc25d0aabf49521dc77c293',
#     'name': "Luigi's Italian Restaurant",
#     'location': {'lat': 44.07379869489241,
#      'lng': -87.73382007341095,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.07379869489241,
#        'lng': -87.73382007341095}],
#      'distance': 57638,
#      'postalCode': '54220',
#      'cc': 'US',
#      'city': 'Manitowoc',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['Manitowoc, WI 54220', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '4c9503d772dd224b248b9f91',
#     'name': 'Ala Roma Pizzeria & Pub',
#     'location': {'address': '171 N Pioneer Rd',
#      'lat': 43.7831157,
#      'lng': -88.47937,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.7831157,
#        'lng': -88.47937}],
#      'distance': 53528,
#      'postalCode': '54935',
#      'cc': 'US',
#      'city': 'Fond du Lac',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['171 N Pioneer Rd',
#       'Fond du Lac, WI 54935',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '56b63966498e095e6c647e11',
#     'name': 'the bathroom (in Italian)',
#     'location': {'lat': 44.073858,
#      'lng': -87.733801,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.073858,
#        'lng': -87.733801}],
#      'distance': 57637,
#      'cc': 'US',
#      'city': 'Manitowoc',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['Manitowoc, WI', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '52bf640211d2680f3c073c27',
#     'name': "Benvenuto's Italian Grill",
#     'location': {'address': '625 Rolling Meadows Dr',
#      'lat': 43.75605763107507,
#      'lng': -88.47657079585785,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.75605763107507,
#        'lng': -88.47657079585785}],
#      'distance': 56501,
#      'postalCode': '54937',
#      'cc': 'US',
#      'city': 'Fond du Lac',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['625 Rolling Meadows Dr',
#       'Fond du Lac, WI 54937',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '53fa6d0d498eacb60d6a6833',
#     'name': 'Bellissimo Ristorante Italiano & Pizzeria',
#     'location': {'address': '103 W Huron St',
#      'lat': 43.96843719482422,
#      'lng': -88.94682312011719,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.96843719482422,
#        'lng': -88.94682312011719}],
#      'distance': 54079,
#      'postalCode': '54923',
#      'cc': 'US',
#      'city': 'Berlin',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['103 W Huron St',
#       'Berlin, WI 54923',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '4ba58105f964a5207f0d39e3',
#     'name': "Luigi's Italian Restaurant",
#     'location': {'address': '1033 22nd St Two Rivers',
#      'lat': 44.15344331628711,
#      'lng': -87.56184415918828,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.15344331628711,
#        'lng': -87.56184415918828}],
#      'distance': 68477,
#      'postalCode': '54241-2724',
#      'cc': 'US',
#      'city': 'Two Rivers',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['1033 22nd St Two Rivers',
#       'Two Rivers, WI 54241-2724',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '576ac9ec498eb4ae0f78ccae',
#     'name': "Maretti's Italian Deli",
#     'location': {'lat': 44.146755,
#      'lng': -87.56801,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.146755,
#        'lng': -87.56801}],
#      'distance': 68132,
#      'cc': 'US',
#      'city': 'Two Rivers',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['Two Rivers, WI', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'shortName': 'Deli / Bodega',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '4c64a6b4b85bef3bbdb2e143',
#     'name': "Luigi's Italian Restaurant",
#     'location': {'address': '2910 Kohler Memorial Dr',
#      'crossStreet': '29th St.',
#      'lat': 43.75688195888104,
#      'lng': -87.74497942759255,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.75688195888104,
#        'lng': -87.74497942759255}],
#      'distance': 77189,
#      'postalCode': '53081',
#      'cc': 'US',
#      'city': 'Sheboygan',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['2910 Kohler Memorial Dr (29th St.)',
#       'Sheboygan, WI 53081',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False},
#    {'id': '4be4c0042457a59398bbaa15',
#     'name': 'Lino Ristorante Italiano',
#     'location': {'address': '422 S Pier Dr',
#      'lat': 43.747976440185106,
#      'lng': -87.70626375575944,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.747976440185106,
#        'lng': -87.70626375575944}],
#      'distance': 80056,
#      'postalCode': '53081',
#      'cc': 'US',
#      'city': 'Sheboygan',
#      'state': 'WI',
#      'country': 'United States',
#      'formattedAddress': ['422 S Pier Dr',
#       'Sheboygan, WI 53081',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550866893',
#     'hasPerk': False}]}}

# %%
# Extract what we need into a dataframe
from pandas.io.json import json_normalize
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...         NaN
# 1  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...         NaN
# 2  [{'id': '4bf58dd8d48988d11e941735', 'name': 'C...         NaN
# 3  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...         NaN
# 4  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...         NaN
#
#   delivery.provider.icon.name delivery.provider.icon.prefix  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#   delivery.provider.icon.sizes delivery.provider.name delivery.url  hasPerk  \
# 0                          NaN                    NaN          NaN    False
# 1                          NaN                    NaN          NaN    False
# 2                          NaN                    NaN          NaN    False
# 3                          NaN                    NaN          NaN    False
# 4                          NaN                    NaN          NaN    False
#
#                          id    location.address  ... location.distance  \
# 0  4b2aeb8df964a5201ab224e3   724 N Casaloma Dr  ...              5516
# 1  4b6dc745f964a520f68e2ce3   503 W College Ave  ...               442
# 2  4ec8545661af9e1430d1a63a                 NaN  ...              4403
# 3  4fad6d83e4b017dfa581928b                 NaN  ...              2739
# 4  4b58fd59f964a520297728e3  1275 N Casaloma Dr  ...              5731
#
#                            location.formattedAddress  \
# 0  [724 N Casaloma Dr, Appleton, WI 54913-8549, U...
# 1  [503 W College Ave, Appleton, WI 54911, United...
# 2                [Appleton, WI 54911, United States]
# 3                [Appleton, WI 54911, United States]
# 4  [1275 N Casaloma Dr, Appleton, WI 54913, Unite...
#
#                              location.labeledLatLngs location.lat  \
# 0  [{'label': 'display', 'lat': 44.2699603455633,...    44.269960
# 1  [{'label': 'display', 'lat': 44.26179255420541...    44.261793
# 2  [{'label': 'display', 'lat': 44.29681015014648...    44.296810
# 3  [{'label': 'display', 'lat': 44.28387281748089...    44.283873
# 4  [{'label': 'display', 'lat': 44.27241936600967...    44.272419
#
#    location.lng location.postalCode location.state  \
# 0    -88.474859          54913-8549             WI
# 1    -88.412234               54911             WI
# 2    -88.382904               54911             WI
# 3    -88.393615               54911             WI
# 4    -88.476918               54913             WI
#
#                            name    referralId venuePage.id
# 0  Carmella's an Italian Bistro  v-1550866893          NaN
# 1                    Victoria's  v-1550866893          NaN
# 2        Italian stallion villa  v-1550866893          NaN
# 3  Scarletini's Italian Cooking  v-1550866893          NaN
# 4                  Olive Garden  v-1550866893          NaN
#
# [5 rows x 24 columns]

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                          name             categories  \
# 0                Carmella's an Italian Bistro     Italian Restaurant
# 1                                  Victoria's     Italian Restaurant
# 2                      Italian stallion villa           Cocktail Bar
# 3                Scarletini's Italian Cooking             Restaurant
# 4                                Olive Garden     Italian Restaurant
# 5                  Luigi's Italian Restaurant     Italian Restaurant
# 6             Luna Italian Restaurant and Mkt     Italian Restaurant
# 7              Rozzi's Italian Deli &  Market          Deli / Bodega
# 8                              Gino's Italian     Italian Restaurant
# 9                       Grazies Italian Grill     Italian Restaurant
# 10         Sammy's Pizza & Italian Restaurant            Pizza Place
# 11                                Benvenuto's     Italian Restaurant
# 12                           Italian Room DLC                   None
# 13                      Grazies Italian Grill     Italian Restaurant
# 14      Jersey's Sports Bar and Italian Grill     Italian Restaurant
# 15                               Italian Rome  General Entertainment
# 16                               Olive Garden     Italian Restaurant
# 17            Bilottis Pizza & Italian Garden     Italian Restaurant
# 18                    Savvy's Italian Cuisine            Pizza Place
# 19                     Luigi's Italian Bistro     Italian Restaurant
# 20                   Italian Palace and Grill                   Food
# 21                  Gino's Italian Restaurant                   None
# 22                 Luigi's Italian Restaurant     Italian Restaurant
# 23                    Ala Roma Pizzeria & Pub     Italian Restaurant
# 24                  the bathroom (in Italian)     Italian Restaurant
# 25                  Benvenuto's Italian Grill     Italian Restaurant
# 26  Bellissimo Ristorante Italiano & Pizzeria     Italian Restaurant
# 27                 Luigi's Italian Restaurant     Italian Restaurant
# 28                     Maretti's Italian Deli          Deli / Bodega
# 29                 Luigi's Italian Restaurant     Italian Restaurant
# 30                   Lino Ristorante Italiano     Italian Restaurant
#
#                     address  cc         city        country    crossStreet  \
# 0         724 N Casaloma Dr  US     Appleton  United States            NaN
# 1         503 W College Ave  US     Appleton  United States            NaN
# 2                       NaN  US     Appleton  United States            NaN
# 3                       NaN  US     Appleton  United States            NaN
# 4        1275 N Casaloma Dr  US     Appleton  United States            NaN
# 5                       NaN  US     Appleton  United States            NaN
# 6       124 W Wisconsin Ave  US       Neenah  United States            NaN
# 7             2450 Velp Ave  US       Howard  United States            NaN
# 8         584 W Johnson St.  US  Fond du Lac  United States            NaN
# 9          2851 S Oneida St  US    Green Bay  United States            NaN
# 10         2161 S Oneida St  US    Green Bay  United States            NaN
# 11         300 S Koeller St  US      Oshkosh  United States  at Witzel Ave
# 12         1415 E Walnut St  US    Green Bay  United States            NaN
# 13                      NaN  US          NaN  United States            NaN
# 14            614 George St  US       Depere  United States            NaN
# 15                      NaN  US    Green Bay  United States            NaN
# 16         2819 S Oneida St  US    Green Bay  United States            NaN
# 17                      NaN  US       Depere  United States            NaN
# 18          1015 W Mason St  US    Green Bay  United States            NaN
# 19  2733 Manitowoc Rd Ste 5  US    Green Bay  United States            NaN
# 20    1216 W Fond du Lac St  US        Ripon  United States            NaN
# 21         584 W Johnson St  US  Fond du Lac  United States            NaN
# 22                      NaN  US    Manitowoc  United States            NaN
# 23         171 N Pioneer Rd  US  Fond du Lac  United States            NaN
# 24                      NaN  US    Manitowoc  United States            NaN
# 25   625 Rolling Meadows Dr  US  Fond du Lac  United States            NaN
# 26           103 W Huron St  US       Berlin  United States            NaN
# 27  1033 22nd St Two Rivers  US   Two Rivers  United States            NaN
# 28                      NaN  US   Two Rivers  United States            NaN
# 29  2910 Kohler Memorial Dr  US    Sheboygan  United States       29th St.
# 30            422 S Pier Dr  US    Sheboygan  United States            NaN
#
#     distance                                   formattedAddress  \
# 0       5516  [724 N Casaloma Dr, Appleton, WI 54913-8549, U...
# 1        442  [503 W College Ave, Appleton, WI 54911, United...
# 2       4403                [Appleton, WI 54911, United States]
# 3       2739                [Appleton, WI 54911, United States]
# 4       5731  [1275 N Casaloma Dr, Appleton, WI 54913, Unite...
# 5       7966                [Appleton, WI 54915, United States]
# 6       9395  [124 W Wisconsin Ave, Neenah, WI 54956, United...
# 7      42855   [2450 Velp Ave, Howard, WI 54303, United States]
# 8      53338  [584 W Johnson St., Fond du Lac, WI 54935, Uni...
# 9      35308  [2851 S Oneida St, Green Bay, WI 54304, United...
# 10     37692  [2161 S Oneida St, Green Bay, WI 54304, United...
# 11     30735  [300 S Koeller St (at Witzel Ave), Oshkosh, WI...
# 12     42817  [1415 E Walnut St, Green Bay, WI 54301, United...
# 13     34458                         [Wisconsin, United States]
# 14     34758   [614 George St, Depere, WI 54115, United States]
# 15     42890                     [Green Bay, WI, United States]
# 16     35522  [2819 S Oneida St, Green Bay, WI 54304, United...
# 17     35705                  [Depere, WI 54115, United States]
# 18     38361  [1015 W Mason St, Green Bay, WI 54303, United ...
# 19     43127  [2733 Manitowoc Rd Ste 5, Green Bay, WI 54311,...
# 20     58117  [1216 W Fond du Lac St, Ripon, WI 54971, Unite...
# 21     53369  [584 W Johnson St, Fond du Lac, WI 54935, Unit...
# 22     57638               [Manitowoc, WI 54220, United States]
# 23     53528  [171 N Pioneer Rd, Fond du Lac, WI 54935, Unit...
# 24     57637                     [Manitowoc, WI, United States]
# 25     56501  [625 Rolling Meadows Dr, Fond du Lac, WI 54937...
# 26     54079  [103 W Huron St, Berlin, WI 54923, United States]
# 27     68477  [1033 22nd St Two Rivers, Two Rivers, WI 54241...
# 28     68132                    [Two Rivers, WI, United States]
# 29     77189  [2910 Kohler Memorial Dr (29th St.), Sheboygan...
# 30     80056  [422 S Pier Dr, Sheboygan, WI 53081, United St...
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'label': 'display', 'lat': 44.2699603455633,...  44.269960 -88.474859
# 1   [{'label': 'display', 'lat': 44.26179255420541...  44.261793 -88.412234
# 2   [{'label': 'display', 'lat': 44.29681015014648...  44.296810 -88.382904
# 3   [{'label': 'display', 'lat': 44.28387281748089...  44.283873 -88.393615
# 4   [{'label': 'display', 'lat': 44.27241936600967...  44.272419 -88.476918
# 5   [{'label': 'display', 'lat': 44.22231292724609...  44.222313 -88.322838
# 6   [{'label': 'display', 'lat': 44.186993, 'lng':...  44.186993 -88.463031
# 7   [{'label': 'display', 'lat': 44.56349730491638...  44.563497 -88.073150
# 8   [{'label': 'display', 'lat': 43.78408615916837...  43.784086 -88.469142
# 9   [{'label': 'display', 'lat': 44.47153254798962...  44.471533 -88.074733
# 10  [{'label': 'display', 'lat': 44.4933218, 'lng'...  44.493322 -88.061944
# 11  [{'label': 'display', 'lat': 44.015244, 'lng':...  44.015244 -88.581741
# 12  [{'label': 'display', 'lat': 44.50710272364985...  44.507103 -87.992974
# 13  [{'label': 'display', 'lat': 44.49487526280353...  44.494875 -88.122830
# 14  [{'label': 'display', 'lat': 44.4489, 'lng': -...  44.448900 -88.057850
# 15  [{'label': 'display', 'lat': 44.49875640869140...  44.498756 -87.982407
# 16  [{'label': 'display', 'lat': 44.4740502548479,...  44.474050 -88.074272
# 17  [{'label': 'display', 'lat': 44.42961674262697...  44.429617 -88.025109
# 18  [{'label': 'display', 'lat': 44.52417, 'lng': ...  44.524170 -88.095190
# 19  [{'label': 'display', 'lat': 44.46470096289037...  44.464701 -87.945691
# 20  [{'label': 'display', 'lat': 43.855568, 'lng':...  43.855568 -88.864246
# 21  [{'label': 'display', 'lat': 43.78382, 'lng': ...  43.783820 -88.469310
# 22  [{'label': 'display', 'lat': 44.07379869489241...  44.073799 -87.733820
# 23  [{'label': 'display', 'lat': 43.7831157, 'lng'...  43.783116 -88.479370
# 24  [{'label': 'display', 'lat': 44.073858, 'lng':...  44.073858 -87.733801
# 25  [{'label': 'display', 'lat': 43.75605763107507...  43.756058 -88.476571
# 26  [{'label': 'display', 'lat': 43.96843719482422...  43.968437 -88.946823
# 27  [{'label': 'display', 'lat': 44.15344331628711...  44.153443 -87.561844
# 28  [{'label': 'display', 'lat': 44.146755, 'lng':...  44.146755 -87.568010
# 29  [{'label': 'display', 'lat': 43.75688195888104...  43.756882 -87.744979
# 30  [{'label': 'display', 'lat': 43.74797644018510...  43.747976 -87.706264
#
#     postalCode      state                        id
# 0   54913-8549         WI  4b2aeb8df964a5201ab224e3
# 1        54911         WI  4b6dc745f964a520f68e2ce3
# 2        54911         WI  4ec8545661af9e1430d1a63a
# 3        54911         WI  4fad6d83e4b017dfa581928b
# 4        54913         WI  4b58fd59f964a520297728e3
# 5        54915         WI  4fcff475e4b01b683f30c149
# 6        54956         WI  4f32792a19836c91c7db3ccd
# 7        54303         WI  4c4a0c425609c9b6804f1f8f
# 8        54935         WI  4bad37a0f964a520613a3be3
# 9        54304         WI  4b74b34ff964a52036ed2de3
# 10       54304         WI  4b8bfd90f964a520ceb632e3
# 11       54902         WI  4c4cb2ae50710f476a5f8132
# 12       54301         WI  507625d5e4b05275689a98ee
# 13         NaN  Wisconsin  4bbe29d30ec69c7430ef5559
# 14       54115         WI  4f3233b219836c91c7c02fb2
# 15         NaN         WI  52ae2d4411d21d133f97578f
# 16       54304         WI  4b97f845f964a520172335e3
# 17       54115         WI  4e7e6c02f5b99ba2ebf64e77
# 18       54303         WI  4f32a1db19836c91c7eaaabb
# 19       54311         WI  4bb779cd3db7b7135d01209a
# 20       54971         WI  4f44d87a19836ed00196ef4a
# 21       54935         WI  5926a29ab546182970906399
# 22       54220         WI  4bc25d0aabf49521dc77c293
# 23       54935         WI  4c9503d772dd224b248b9f91
# 24         NaN         WI  56b63966498e095e6c647e11
# 25       54937         WI  52bf640211d2680f3c073c27
# 26       54923         WI  53fa6d0d498eacb60d6a6833
# 27  54241-2724         WI  4ba58105f964a5207f0d39e3
# 28         NaN         WI  576ac9ec498eb4ae0f78ccae
# 29       53081         WI  4c64a6b4b85bef3bbdb2e143
# 30       53081         WI  4be4c0042457a59398bbaa15

# %% [markdown]
# ## Let's map those to visualize where they are located.

# %%
dataframe_filtered.name
# Out:
# 0                  Carmella's an Italian Bistro
# 1                                    Victoria's
# 2                        Italian stallion villa
# 3                  Scarletini's Italian Cooking
# 4                                  Olive Garden
# 5                    Luigi's Italian Restaurant
# 6               Luna Italian Restaurant and Mkt
# 7                Rozzi's Italian Deli &  Market
# 8                                Gino's Italian
# 9                         Grazies Italian Grill
# 10           Sammy's Pizza & Italian Restaurant
# 11                                  Benvenuto's
# 12                             Italian Room DLC
# 13                        Grazies Italian Grill
# 14        Jersey's Sports Bar and Italian Grill
# 15                                 Italian Rome
# 16                                 Olive Garden
# 17              Bilottis Pizza & Italian Garden
# 18                      Savvy's Italian Cuisine
# 19                       Luigi's Italian Bistro
# 20                     Italian Palace and Grill
# 21                    Gino's Italian Restaurant
# 22                   Luigi's Italian Restaurant
# 23                      Ala Roma Pizzeria & Pub
# 24                    the bathroom (in Italian)
# 25                    Benvenuto's Italian Grill
# 26    Bellissimo Ristorante Italiano & Pizzeria
# 27                   Luigi's Italian Restaurant
# 28                       Maretti's Italian Deli
# 29                   Luigi's Italian Restaurant
# 30                     Lino Ristorante Italiano
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[gt_latitude, gt_longitude], zoom_start=10) # generate map centered around Appleton

# add a red circle marker to represent the Appleton
folium.features.CircleMarker(
    [gt_latitude, gt_longitude],
    radius=10,
    color='red',
    popup='Appleton',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.name):
    popup = folium.Popup(label, parse_html=True)
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=popup,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)


# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## That's better. Let's add that map to our map of state parks and walleye lakes.

# %%
# add a red circle marker to represent the Appleton
folium.features.CircleMarker(
    [gt_latitude, gt_longitude],
    radius=8,
    color='red',
    popup='Appleton',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(wisc_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.name):
    popup = folium.Popup(label, parse_html=True)
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=popup,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(wisc_map)

wisc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Out of curiousity, let's explore one of the Italian restaurants to see if any tips say anything about gluten-free food appropriate for someone with Celiac disease.

# %%
venue_id = '4b2aeb8df964a5201ab224e3' # ID of Carmella's
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4b2aeb8df964a5201ab224e3?client_id=2YXOIKQTLPEEBMTAKN1PXAHCY2N4L23U4EXKWJEGLQLV1R02&client_secret=RI1RD132ULSAONFM2EAZTI0H5OBNG0H441R5J1IFN2UBZCRO&v=20180604'

# %%
# Send get request for result
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'hasMenu', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'menu', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4b2aeb8df964a5201ab224e3',
#  'name': "Carmella's an Italian Bistro",
#  'contact': {'phone': '9208824044', 'formattedPhone': '(920) 882-4044'},
#  'location': {'address': '724 N Casaloma Dr',
#   'lat': 44.2699603455633,
#   'lng': -88.47485930580342,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 44.2699603455633,
#     'lng': -88.47485930580342}],
#   'postalCode': '54913-8549',
#   'cc': 'US',
#   'city': 'Appleton',
#   'state': 'WI',
#   'country': 'United States',
#   'formattedAddress': ['724 N Casaloma Dr',
#    'Appleton, WI 54913-8549',
#    'United States']},
#  'canonicalUrl': 'https://foursquare.com/v/carmellas-an-italian-bistro/4b2aeb8df964a5201ab224e3',
#  'categories': [{'id': '4bf58dd8d48988d110941735',
#    'name': 'Italian Restaurant',
#    'pluralName': 'Italian Restaurants',
#    'shortName': 'Italian',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': False,
#  'stats': {'tipCount': 52},
#  'url': 'http://carmellasbistro.com',
#  'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'},
#  'hasMenu': True,
#  'likes': {'count': 111,
#   'groups': [{'type': 'others', 'count': 111, 'items': []}],
#   'summary': '111 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 9.0,
#  'ratingColor': '00B551',
#  'ratingSignals': 164,
#  'menu': {'type': 'Menu',
#   'label': 'Menu',
#   'anchor': 'View Menu',
#   'url': 'https://foursquare.com/v/carmellas-an-italian-bistro/4b2aeb8df964a5201ab224e3/menu',
#   'mobileUrl': 'https://foursquare.com/v/4b2aeb8df964a5201ab224e3/device_menu'},
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 108,
#   'groups': [{'type': 'checkin',
#     'name': "Friends' check-in photos",
#     'count': 0,
#     'items': []},
#    {'type': 'venue',
#     'name': 'Venue photos',
#     'count': 108,
#     'items': [{'id': '4e4015ae483b04e17ab79359',
#       'createdAt': 1312822702,
#       'source': {'name': 'Foursquare for iOS',
#        'url': 'https://foursquare.com/download/#/iphone'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/430JQTRXJARMGQYIMBN0UWXU5NPLUBJXLGA32LKCLHTQUCA2.jpg',
#       'width': 720,
#       'height': 537,
#       'user': {'id': '10679330',
#        'firstName': 'Chase',
#        'lastName': 'Gintner',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/ACYHCFBUFIOYC4XC.jpg'}},
#       'visibility': 'public'},
#      {'id': '510abe3be4b08e345fe42a18',
#       'createdAt': 1359658555,
#       'source': {'name': 'Foursquare for iOS',
#        'url': 'https://foursquare.com/download/#/iphone'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/29255581_ZCjNhtUjKDeeV6QR5KqS0oBzD6Kz6TXw53ucsIUVV0M.jpg',
#       'width': 960,
#       'height': 720,
#       'user': {'id': '29255581',
#        'firstName': 'Jan',
#        'lastName': 'Klingberg',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/BCBSSUWMVA3QEG2A.jpg'}},
#       'visibility': 'public'}]}],
#   'summary': '0 photos'},
#  'reasons': {'count': 1,
#   'items': [{'summary': 'Lots of people like this place',
#     'type': 'general',
#     'reasonName': 'rawLikesReason'}]},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1261104013,
#  'tips': {'count': 52,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 52,
#     'items': [{'id': '4fafeb0ee4b06952e00126b8',
#       'createdAt': 1336929038,
#       'text': 'Kallie is a great waitress here!!',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/4fafeb0ee4b06952e00126b8',
#       'lang': 'en',
#       'likes': {'count': 4,
#        'groups': [{'type': 'others',
#          'count': 4,
#          'items': [{'id': '81834045',
#            'firstName': 'N',
#            'lastName': 'P',
#            'gender': 'none',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/blank_boy.png',
#             'default': True}},
#           {'id': '39991457',
#            'firstName': 'Jannis',
#            'lastName': 'B.',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/39991457-4LF3WSPT3SRXZCD0.jpg'}},
#           {'id': '36214852',
#            'firstName': 'lisa',
#            'lastName': 'johnson',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/blank_girl.png',
#             'default': True}},
#           {'id': '1943003',
#            'firstName': 'Kallie',
#            'lastName': 'Palm',
#            'gender': 'none',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/VVP0EI3S0RN22XZ0.jpg'}}]}],
#        'summary': '4 likes'},
#       'logView': True,
#       'agreeCount': 4,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'id': '567572',
#        'firstName': 'Mark P',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/567572-V0WNVFQOQA3IRPFL.jpg'}}},
#      {'id': '4cbe017f28d176b0f216226e',
#       'createdAt': 1287520639,
#       'text': 'The pappardelle is so delicious! Love this restaurant.',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/4cbe017f28d176b0f216226e',
#       'lang': 'en',
#       'likes': {'count': 4,
#        'groups': [{'type': 'others', 'count': 4, 'items': []}],
#        'summary': '4 likes'},
#       'logView': True,
#       'agreeCount': 0,
#       'disagreeCount': 0,
#       'todo': {'count': 3},
#       'user': {'id': '424246',
#        'firstName': 'Erin',
#        'lastName': 'Dee',
#        'gender': 'female',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/LUI1F4ZIKPK2H3B2.jpg'}}}]}]},
#  'shortUrl': 'http://4sq.com/97WxFA',
#  'timeZone': 'America/Chicago',
#  'listed': {'count': 34,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 34,
#     'items': [{'id': '57f2b0c4498edd862c70aff0',
#       'name': "A State-by-State Guide to America's Best Pasta",
#       'description': "Pappardelle, gnocchi, lasagna, ravioli... the options are endless when you've got a hankering for pasta. We rounded up the best spot in every state for the comfort carb.",
#       'type': 'others',
#       'user': {'id': '23438729',
#        'firstName': 'Foursquare City Guide',
#        'gender': 'none',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/23438729-TODURDIUDUMY4JF5.png'},
#        'type': 'page'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/foursquare/list/a-statebystate-guide-to-americas-best-pasta',
#       'canonicalUrl': 'https://foursquare.com/foursquare/list/a-statebystate-guide-to-americas-best-pasta',
#       'createdAt': 1475522756,
#       'updatedAt': 1477092225,
#       'photo': {'id': '5533033a498e1144453f4957',
#        'createdAt': 1429406522,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/21563126_OoqJ0sK02NvMz1fnzR7MJUDecllpbuaj-c23hUJhDHI.jpg',
#        'width': 1920,
#        'height': 1920,
#        'user': {'id': '21563126',
#         'firstName': 'Richard',
#         'lastName': 'Revilla',
#         'gender': 'male',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/21563126_v05J1KPw_SVj6Ehq9g8B9jeAGjFUMsU5QGl-NZ8inUQ7pKQm5bKplW37EmR7jS2A7GYPBBAtl.jpg'}},
#        'visibility': 'public'},
#       'logView': True,
#       'guideType': 'bestOf',
#       'guide': True,
#       'followers': {'count': 213},
#       'listItems': {'count': 51,
#        'items': [{'id': 't542ee5b7498e922e2a055417',
#          'createdAt': 1475526736,
#          'photo': {'id': '514e41abe4b089e308fefcd6',
#           'createdAt': 1364083115,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/32338618_aKQTF_Rg35SV9PhSYL4_PsXaVnVQA7ByjRdngJ1RvjM.jpg',
#           'width': 960,
#           'height': 720,
#           'user': {'id': '32338618',
#            'firstName': 'Julie',
#            'lastName': 'Fronsee',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/32338618-AZDFVUSVCEJUQO3D.jpg'}},
#           'visibility': 'public'}}]}},
#      {'id': '533fceb9498eb8921c10c714',
#       'name': 'Fancy',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '83038796',
#        'firstName': 'Adam',
#        'lastName': 'Shea',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/83038796-CCPCO2IG1VPUHN2U.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/irishfisherman4/list/fancy',
#       'canonicalUrl': 'https://foursquare.com/irishfisherman4/list/fancy',
#       'createdAt': 1396690617,
#       'updatedAt': 1396721170,
#       'followers': {'count': 2},
#       'listItems': {'count': 24,
#        'items': [{'id': 'v4b2aeb8df964a5201ab224e3',
#          'createdAt': 1396690809}]}},
#      {'id': '4ed821f09a5286d91c9c0aad',
#       'name': 'favorite places to visit',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '2938092',
#        'firstName': 'Aaron',
#        'lastName': 'Ebert',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/2938092-LN5TMQ4FGO2UYTSR.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': True,
#       'url': '/user/2938092/list/favorite-places-to-visit',
#       'canonicalUrl': 'https://foursquare.com/user/2938092/list/favorite-places-to-visit',
#       'createdAt': 1322787312,
#       'updatedAt': 1497206364,
#       'photo': {'id': '53d994bf498ec9febddd80bc',
#        'createdAt': 1406768319,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/8368271_rke8L8FdIqCPeMgML3RXX2WUlPXvnub_rgBl2EFQ8mQ.jpg',
#        'width': 720,
#        'height': 960,
#        'user': {'id': '8368271',
#         'firstName': 'Cassandra',
#         'lastName': 'De Ruyter',
#         'gender': 'female',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/P2V0FWWQZ35VTW41.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 10},
#       'listItems': {'count': 116,
#        'items': [{'id': 'v4b2aeb8df964a5201ab224e3',
#          'createdAt': 1322787521}]}},
#      {'id': '55d50b02498e9f7b81ae8ca0',
#       'name': 'The Best of Green Bay',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '2815286',
#        'firstName': 'Morgan',
#        'lastName': 'B',
#        'gender': 'female',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/YAMNBH2EXIDPRAWL.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/morganabigail/list/the-best-of-green-bay',
#       'canonicalUrl': 'https://foursquare.com/morganabigail/list/the-best-of-green-bay',
#       'createdAt': 1440025346,
#       'updatedAt': 1538438853,
#       'photo': {'id': '537fc409498e34a43bdfa47e',
#        'createdAt': 1400882185,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/46310868_8mvwBldXIUMVr7RxLaH-6ID2XvfFcKIOwNCogSmTFuI.jpg',
#        'width': 640,
#        'height': 640,
#        'user': {'id': '46310868',
#         'firstName': 'Zsófia',
#         'lastName': 'Short',
#         'gender': 'female',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/U1GL2AQ45FBJM3BZ.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 3},
#       'listItems': {'count': 58,
#        'items': [{'id': 't4cbe017f28d176b0f216226e',
#          'createdAt': 1440036485,
#          'photo': {'id': '53fcdbab498e7065100efadc',
#           'createdAt': 1409080235,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/32202379_jJIeC2vfQLLWzxvYB3jXqRpeBOh7we3cvuUrVikpMfI.jpg',
#           'width': 640,
#           'height': 640,
#           'user': {'id': '32202379',
#            'firstName': 'Karin',
#            'lastName': 'Farley',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/ZNUYJ1H3O4DZW3K5.jpg'}},
#           'visibility': 'public'}}]}}]}]},
#  'hours': {'status': 'Open until 10:00 PM',
#   'richStatus': {'entities': [], 'text': 'Open until 10:00 PM'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Thu, Sun',
#     'open': [{'renderedTime': '11:00 AM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Fri–Sat',
#     'includesToday': True,
#     'open': [{'renderedTime': '11:00 AM–10:00 PM'}],
#     'segments': []}]},
#  'popular': {'isOpen': False,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '11:00 AM–2:00 PM'},
#      {'renderedTime': '4:00 PM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '11:00 AM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '10:00 AM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': '10:00 AM–2:00 PM'},
#      {'renderedTime': '5:00 PM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Tue',
#     'open': [{'renderedTime': '10:00 AM–1:00 PM'},
#      {'renderedTime': '5:00 PM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Wed',
#     'open': [{'renderedTime': '11:00 AM–1:00 PM'},
#      {'renderedTime': '4:00 PM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Thu',
#     'open': [{'renderedTime': '11:00 AM–1:00 PM'},
#      {'renderedTime': '3:00 PM–9:00 PM'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '$$',
#     'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$$', 'priceTier': 2}]},
#    {'type': 'reservations',
#     'name': 'Reservations',
#     'summary': 'Reservations',
#     'count': 3,
#     'items': [{'displayName': 'Reservations', 'displayValue': 'Yes'}]},
#    {'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'count': 7,
#     'items': [{'displayName': 'Credit Cards',
#       'displayValue': 'Yes (incl. American Express)'}]},
#    {'type': 'outdoorSeating',
#     'name': 'Outdoor Seating',
#     'summary': 'Outdoor Seating',
#     'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'Yes'}]},
#    {'type': 'wifi',
#     'name': 'Wi-Fi',
#     'summary': 'Wi-Fi',
#     'count': 1,
#     'items': [{'displayName': 'Wi-Fi', 'displayValue': 'Yes'}]},
#    {'type': 'serves',
#     'name': 'Menus',
#     'summary': 'Dinner, Lunch & more',
#     'count': 8,
#     'items': [{'displayName': 'Brunch', 'displayValue': 'Brunch'},
#      {'displayName': 'Lunch', 'displayValue': 'Lunch'},
#      {'displayName': 'Dinner', 'displayValue': 'Dinner'}]},
#    {'type': 'drinks',
#     'name': 'Drinks',
#     'summary': 'Wine, Full Bar & Cocktails',
#     'count': 5,
#     'items': [{'displayName': 'Wine', 'displayValue': 'Wine'},
#      {'displayName': 'Full Bar', 'displayValue': 'Full Bar'},
#      {'displayName': 'Cocktails', 'displayValue': 'Cocktails'}]},
#    {'type': 'diningOptions',
#     'name': 'Dining Options',
#     'count': 5,
#     'items': [{'displayName': 'Delivery', 'displayValue': 'No Delivery'}]}]},
#  'bestPhoto': {'id': '4e4015ae483b04e17ab79359',
#   'createdAt': 1312822702,
#   'source': {'name': 'Foursquare for iOS',
#    'url': 'https://foursquare.com/download/#/iphone'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/430JQTRXJARMGQYIMBN0UWXU5NPLUBJXLGA32LKCLHTQUCA2.jpg',
#   'width': 720,
#   'height': 537,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '4e4015ae483b04e17ab79359',
#    'value': -3090240},
#   'highlightTextColor': {'photoId': '4e4015ae483b04e17ab79359',
#    'value': -16777216},
#   'algoVersion': 3}}

# %%
# Get Carmella's overall rating
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 9.0

# %% [markdown]
# ## That's excellent!  Let's get the tips.

# %%
result['response']['venue']['tips']['count']
# Out:
# 52

# %%
## Tips
limit = 52 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c7059db6a60714c802a723a'},
#  'response': {'tips': {'count': 52,
#    'items': [{'id': '503d639de4b03f28bce90d65',
#      'createdAt': 1346200477,
#      'text': 'An amazing Italian meal! Great service, wonderful atmosphere. A lovely patio -with a wait. A true Italian menu with a variety of selections. Not great for vegs - chick broth.  A true gem in Apltn!',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/503d639de4b03f28bce90d65',
#      'photo': {'id': '503d63a0e4b094d609976312',
#       'createdAt': 1346200480,
#       'source': {'name': 'Foursquare for iOS',
#        'url': 'https://foursquare.com/download/#/iphone'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/vWPcdYjSZpSFlDSCzwrOAwoseT-GNymJGfqmie6k61M.jpg',
#       'width': 537,
#       'height': 720,
#       'visibility': 'public'},
#      'photourl': 'https://fastly.4sqi.net/img/general/original/vWPcdYjSZpSFlDSCzwrOAwoseT-GNymJGfqmie6k61M.jpg',
#      'lang': 'en',
#      'likes': {'count': 1,
#       'groups': [{'type': 'others',
#         'count': 1,
#         'items': [{'id': '45992534',
#           'firstName': 'Dawn',
#           'gender': 'female',
#           'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#            'suffix': '/5R43AYG0F21J11NP.jpg'}}]}],
#       'summary': '1 like'},
#      'logView': True,
#      'agreeCount': 1,
#      'disagreeCount': 0,
#      'todo': {'count': 0},
#      'user': {'id': '5085901',
#       'firstName': 'Leila',
#       'gender': 'female',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/1NAOEBXTD3TTT4VG.jpg'}},
#      'authorInteractionType': 'liked'},
#     {'id': '5642d5b9498ebe8782f359de',
#      'createdAt': 1447220665,
#      'text': "My absolute favorite Italian place within driving distance from my home.  Great atmosphere inside and outside on patio.  You can't go wrong with anything on the menu.  Have reservations.",
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/5642d5b9498ebe8782f359de',
#      'photo': {'id': '5642d5b9498ebe8782f359dd',
#       'createdAt': 1447220665,
#       'source': {'name': 'Foursquare for iOS',
#        'url': 'https://foursquare.com/download/#/iphone'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/d7D8S3YSNYN4lU7HhwZkO9_I5HGg4jBaE8YRc38XPI0.jpg',
#       'width': 720,
#       'height': 540,
#       'visibility': 'public'},
#      'photourl': 'https://fastly.4sqi.net/img/general/original/d7D8S3YSNYN4lU7HhwZkO9_I5HGg4jBaE8YRc38XPI0.jpg',
#      'lang': 'en',
#      'likes': {'count': 0, 'groups': []},
#      'logView': True,
#      'agreeCount': 0,
#      'disagreeCount': 0,
#      'todo': {'count': 0},
#      'user': {'id': '23898158',
#       'firstName': 'Josh',
#       'lastName': 'Jandrain',
#       'gender': 'male',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/CGZULSP0DHQBJGY5.jpg'}},
#      'authorInteractionType': 'liked'}]}}}

# %%
# Get tips
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'photo', 'photourl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user', 'authorInteractionType'])

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
#                                                                                                                                                                                                    text  \
# 0  An amazing Italian meal! Great service, wonderful atmosphere. A lovely patio -with a wait. A true Italian menu with a variety of selections. Not great for vegs - chick broth.  A true gem in Apltn!
# 1  My absolute favorite Italian place within driving distance from my home.  Great atmosphere inside and outside on patio.  You can't go wrong with anything on the menu.  Have reservations.
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  1           0              503d639de4b03f28bce90d65  Leila
# 1  0           0              5642d5b9498ebe8782f359de  Josh
#
#   user.lastName user.gender   user.id
# 0  NaN           female      5085901
# 1  Jandrain      male        23898158

# %% [markdown]
# ## That was disappointing. I was expecting 52 tips, not 2. I'm going to try one more restaurant.

# %%
# I'm trying Victoria's now because my current location has an Italian restaurant with the same name. They are not a chain so I am very curious.
venue_id = '4b6dc745f964a520f68e2ce3' # ID of Victoria's
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4b6dc745f964a520f68e2ce3?client_id=2YXOIKQTLPEEBMTAKN1PXAHCY2N4L23U4EXKWJEGLQLV1R02&client_secret=RI1RD132ULSAONFM2EAZTI0H5OBNG0H441R5J1IFN2UBZCRO&v=20180604'

# %%
# Send get request for result
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'hasMenu', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'menu', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4b6dc745f964a520f68e2ce3',
#  'name': "Victoria's",
#  'contact': {'phone': '9207300595', 'formattedPhone': '(920) 730-0595'},
#  'location': {'address': '503 W College Ave',
#   'lat': 44.26179255420541,
#   'lng': -88.41223429886749,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 44.26179255420541,
#     'lng': -88.41223429886749}],
#   'postalCode': '54911',
#   'cc': 'US',
#   'city': 'Appleton',
#   'state': 'WI',
#   'country': 'United States',
#   'formattedAddress': ['503 W College Ave',
#    'Appleton, WI 54911',
#    'United States']},
#  'canonicalUrl': 'https://foursquare.com/v/victorias/4b6dc745f964a520f68e2ce3',
#  'categories': [{'id': '4bf58dd8d48988d110941735',
#    'name': 'Italian Restaurant',
#    'pluralName': 'Italian Restaurants',
#    'shortName': 'Italian',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': False,
#  'stats': {'tipCount': 37},
#  'url': 'http://victoriasitalian.com',
#  'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'},
#  'hasMenu': True,
#  'likes': {'count': 54,
#   'groups': [{'type': 'others', 'count': 54, 'items': []}],
#   'summary': '54 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 7.4,
#  'ratingColor': 'C5DE35',
#  'ratingSignals': 97,
#  'menu': {'type': 'Menu',
#   'label': 'Menu',
#   'anchor': 'View Menu',
#   'url': 'https://foursquare.com/v/victorias/4b6dc745f964a520f68e2ce3/menu',
#   'mobileUrl': 'https://foursquare.com/v/4b6dc745f964a520f68e2ce3/device_menu'},
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 35,
#   'groups': [{'type': 'checkin',
#     'name': "Friends' check-in photos",
#     'count': 0,
#     'items': []},
#    {'type': 'venue',
#     'name': 'Venue photos',
#     'count': 35,
#     'items': [{'id': '5373a132498e8c2e944ec8bc',
#       'createdAt': 1400086834,
#       'source': {'name': 'Foursquare for iOS',
#        'url': 'https://foursquare.com/download/#/iphone'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/5065896_GhXV7BfQn8Omqg3geN5iTqvhftQKtGAAsENCk1QY0dE.jpg',
#       'width': 960,
#       'height': 720,
#       'user': {'id': '5065896',
#        'firstName': 'Bonnie',
#        'lastName': 'B',
#        'gender': 'female',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/ZNPAYRC3Z2GVC4MZ.jpg'}},
#       'visibility': 'public'},
#      {'id': '51707773e4b0d60992674688',
#       'createdAt': 1366325107,
#       'source': {'name': 'Foursquare for iOS',
#        'url': 'https://foursquare.com/download/#/iphone'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/11543412_udhNNXbqUAO2TTnACDGtIetIrB_6Q3bcgZMAz70b08g.jpg',
#       'width': 1440,
#       'height': 1920,
#       'user': {'id': '11543412',
#        'firstName': 'Keith',
#        'lastName': 'Kmett',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/11543412_4X0gskYF_bIILQK10pPvZwgrkYmKdc8c-7JRPyHJAIqUqSMF0JtySazvAqz3CQ-a5iMvYy_bG.jpg'}},
#       'visibility': 'public'}]}],
#   'summary': '0 photos'},
#  'reasons': {'count': 1,
#   'items': [{'summary': 'Lots of people like this place',
#     'type': 'general',
#     'reasonName': 'rawLikesReason'}]},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1265485637,
#  'tips': {'count': 37,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 37,
#     'items': [{'id': '4d5c73021e43236a6d2b1a83',
#       'createdAt': 1297904386,
#       'text': 'Server took my meal from me while I was in mid-bite with over half the plate full. You stay classy....',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/4d5c73021e43236a6d2b1a83',
#       'lang': 'en',
#       'likes': {'count': 4,
#        'groups': [{'type': 'others',
#          'count': 4,
#          'items': [{'id': '1825580',
#            'firstName': 'Nick',
#            'lastName': 'Manderfield',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/4Q2AHYIXXPJYJ0ED.jpg'}}]}],
#        'summary': '4 likes'},
#       'logView': True,
#       'agreeCount': 1,
#       'disagreeCount': 1,
#       'todo': {'count': 0},
#       'user': {'id': '2672877',
#        'firstName': 'Eric',
#        'lastName': 'Balkman',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/2672877_vs89na2p_zS6MUD1GmWUPawH9b7u5ncxvTE-BEl6-ZXlbm-T9Y0bHLBLIKps-yUx3tVfRvmd4.jpg'}},
#       'authorInteractionType': 'meh'},
#      {'id': '521a180311d28f3e265fad0f',
#       'createdAt': 1377441795,
#       'text': 'The Eggplant Parmagiana - portion HUGE, enough for 3 people! Tasty, but not impressive. Coffee was great!',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/521a180311d28f3e265fad0f',
#       'lang': 'en',
#       'likes': {'count': 3,
#        'groups': [{'type': 'others',
#          'count': 3,
#          'items': [{'id': '14192864',
#            'firstName': 'Franz',
#            'lastName': 'Grzeschniok',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/GZKG34XIGEEWLWT1.jpg'}},
#           {'id': '54402459',
#            'firstName': 'Cristinne',
#            'lastName': 'Brandao',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/54402459-P4YF1QAJMENLPLN4.jpg'}},
#           {'id': '22506452',
#            'firstName': 'Ramiro',
#            'lastName': 'Benevides',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/FITVTDYMY5KOPURC.jpg'}}]}],
#        'summary': '3 likes'},
#       'logView': True,
#       'agreeCount': 3,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'id': '63011094',
#        'firstName': 'Cree',
#        'lastName': 'Mayden',
#        'gender': 'female',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/63011094_zWM50AF-_HH63B33NZIFR_KgJxNUrS2POW3HISK_WURN1_y6WnCP7RRo2xHpgUrU9dfHHbOs0.jpg'}}}]}]},
#  'shortUrl': 'http://4sq.com/9BBQVA',
#  'timeZone': 'America/Chicago',
#  'listed': {'count': 12,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 12,
#     'items': [{'id': '4e7e98e20cd66e03df31e825',
#       'name': 'Top 10 restaurants when money is no object',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '13989753',
#        'firstName': 'NICHOLAS',
#        'lastName': 'W.',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/LRK10CP5T1TKCHPZ.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/nwill1981/list/top-10-restaurants-when-money-is-no-object',
#       'canonicalUrl': 'https://foursquare.com/nwill1981/list/top-10-restaurants-when-money-is-no-object',
#       'createdAt': 1316919522,
#       'updatedAt': 1316919810,
#       'followers': {'count': 13},
#       'listItems': {'count': 26,
#        'items': [{'id': 'v4b6dc745f964a520f68e2ce3',
#          'createdAt': 1316919597}]}},
#      {'id': '50130f5be4b09075805181a9',
#       'name': 'Top Ten List~Appleton',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '21814860',
#        'firstName': 'Angie',
#        'lastName': 'Ballard',
#        'gender': 'female',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/K1VP2VKMZKG2X0C4.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/21814860/list/top-ten-listappleton',
#       'canonicalUrl': 'https://foursquare.com/user/21814860/list/top-ten-listappleton',
#       'createdAt': 1343426395,
#       'updatedAt': 1348088505,
#       'followers': {'count': 0},
#       'listItems': {'count': 10,
#        'items': [{'id': 'v4b6dc745f964a520f68e2ce3',
#          'createdAt': 1343426623}]}},
#      {'id': '4e7bf1531850491d9ea9a4fd',
#       'name': '20 favorite restaurants',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '10730090',
#        'firstName': 'Mike',
#        'lastName': 'Langworthy',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/ZEBTK4RLDH1PJ0SU.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/10730090/list/20-favorite-restaurants',
#       'canonicalUrl': 'https://foursquare.com/user/10730090/list/20-favorite-restaurants',
#       'createdAt': 1316745555,
#       'updatedAt': 1316745841,
#       'followers': {'count': 8},
#       'listItems': {'count': 20,
#        'items': [{'id': 'v4b6dc745f964a520f68e2ce3',
#          'createdAt': 1316745568}]}},
#      {'id': '4ed821f09a5286d91c9c0aad',
#       'name': 'favorite places to visit',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '2938092',
#        'firstName': 'Aaron',
#        'lastName': 'Ebert',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/2938092-LN5TMQ4FGO2UYTSR.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': True,
#       'url': '/user/2938092/list/favorite-places-to-visit',
#       'canonicalUrl': 'https://foursquare.com/user/2938092/list/favorite-places-to-visit',
#       'createdAt': 1322787312,
#       'updatedAt': 1497206364,
#       'photo': {'id': '53d994bf498ec9febddd80bc',
#        'createdAt': 1406768319,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/8368271_rke8L8FdIqCPeMgML3RXX2WUlPXvnub_rgBl2EFQ8mQ.jpg',
#        'width': 720,
#        'height': 960,
#        'user': {'id': '8368271',
#         'firstName': 'Cassandra',
#         'lastName': 'De Ruyter',
#         'gender': 'female',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/P2V0FWWQZ35VTW41.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 10},
#       'listItems': {'count': 116,
#        'items': [{'id': 'v4b6dc745f964a520f68e2ce3',
#          'createdAt': 1408141317,
#          'photo': {'id': '5373a132498e8c2e944ec8bc',
#           'createdAt': 1400086834,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/5065896_GhXV7BfQn8Omqg3geN5iTqvhftQKtGAAsENCk1QY0dE.jpg',
#           'width': 960,
#           'height': 720,
#           'user': {'id': '5065896',
#            'firstName': 'Bonnie',
#            'lastName': 'B',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/ZNPAYRC3Z2GVC4MZ.jpg'}},
#           'visibility': 'public'}}]}}]}]},
#  'hours': {'status': 'Open until 9:00 PM',
#   'richStatus': {'entities': [], 'text': 'Open until 9:00 PM'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Sun',
#     'includesToday': True,
#     'open': [{'renderedTime': '11:00 AM–9:00 PM'}],
#     'segments': []}]},
#  'popular': {'isOpen': False,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '1:00 PM–2:00 PM'},
#      {'renderedTime': '4:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': 'Noon–10:00 PM'}],
#     'segments': []},
#    {'days': 'Sun', 'open': [{'renderedTime': 'Noon–8:00 PM'}], 'segments': []},
#    {'days': 'Mon–Tue',
#     'open': [{'renderedTime': '5:00 PM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Wed',
#     'open': [{'renderedTime': 'Noon–1:00 PM'},
#      {'renderedTime': '5:00 PM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Thu',
#     'open': [{'renderedTime': '1:00 PM–2:00 PM'},
#      {'renderedTime': '5:00 PM–10:00 PM'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '$$',
#     'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$$', 'priceTier': 2}]},
#    {'type': 'reservations',
#     'name': 'Reservations',
#     'summary': 'Reservations',
#     'count': 3,
#     'items': [{'displayName': 'Reservations', 'displayValue': 'Yes'}]},
#    {'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'count': 7,
#     'items': [{'displayName': 'Credit Cards',
#       'displayValue': 'Yes (incl. American Express)'}]},
#    {'type': 'outdoorSeating',
#     'name': 'Outdoor Seating',
#     'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'No'}]},
#    {'type': 'serves',
#     'name': 'Menus',
#     'summary': 'Dinner, Lunch & more',
#     'count': 8,
#     'items': [{'displayName': 'Brunch', 'displayValue': 'Brunch'},
#      {'displayName': 'Lunch', 'displayValue': 'Lunch'},
#      {'displayName': 'Dinner', 'displayValue': 'Dinner'}]},
#    {'type': 'drinks',
#     'name': 'Drinks',
#     'summary': 'Full Bar',
#     'count': 5,
#     'items': [{'displayName': 'Full Bar', 'displayValue': 'Full Bar'}]},
#    {'type': 'diningOptions',
#     'name': 'Dining Options',
#     'summary': 'Delivery',
#     'count': 5,
#     'items': [{'displayName': 'Delivery', 'displayValue': 'Delivery'}]}]},
#  'bestPhoto': {'id': '5373a132498e8c2e944ec8bc',
#   'createdAt': 1400086834,
#   'source': {'name': 'Foursquare for iOS',
#    'url': 'https://foursquare.com/download/#/iphone'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/5065896_GhXV7BfQn8Omqg3geN5iTqvhftQKtGAAsENCk1QY0dE.jpg',
#   'width': 960,
#   'height': 720,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '5373a132498e8c2e944ec8bc',
#    'value': -8357752},
#   'highlightTextColor': {'photoId': '5373a132498e8c2e944ec8bc',
#    'value': -16777216},
#   'algoVersion': 3}}

# %%
# Get Victoria's overall rating
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.4

# %%
result['response']['venue']['tips']['count']
# Out:
# 37

# %%
## Tips
limit = 37 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c7059e04434b95786c2df49'},
#  'response': {'tips': {'count': 38,
#    'items': [{'id': '544861f7498e54d3775bd639',
#      'createdAt': 1414029815,
#      'text': 'Great service I came in 15 minutes before closing and the I felt very welcome. A lot of places try to turn you away. By portions are huge .',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/544861f7498e54d3775bd639',
#      'lang': 'en',
#      'likes': {'count': 0, 'groups': []},
#      'logView': True,
#      'agreeCount': 0,
#      'disagreeCount': 0,
#      'todo': {'count': 0},
#      'user': {'id': '84330972',
#       'firstName': 'Marty',
#       'lastName': 'Muffler',
#       'gender': 'male',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/blank_boy.png',
#        'default': True}},
#      'authorInteractionType': 'liked'},
#     {'id': '4edd900a77c8274e00ead77e',
#      'createdAt': 1323143178,
#      'text': 'Great food at an affordable price! Weekday 2 for 1 specials in the bar! Be sure to take advantage of that and tip your server/bartender.',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/4edd900a77c8274e00ead77e',
#      'lang': 'en',
#      'likes': {'count': 0, 'groups': []},
#      'logView': True,
#      'agreeCount': 0,
#      'disagreeCount': 0,
#      'todo': {'count': 1},
#      'user': {'id': '7687985',
#       'firstName': 'Tannah',
#       'lastName': 'Bing',
#       'gender': 'female',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/LMHGDVIIRJDTRQPP.jpg'}}}]}}}

# %%
# Get tips
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user', 'authorInteractionType'])

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
#                                                                                                                                           text  \
# 0  Great service I came in 15 minutes before closing and the I felt very welcome. A lot of places try to turn you away. By portions are huge .
# 1  Great food at an affordable price! Weekday 2 for 1 specials in the bar! Be sure to take advantage of that and tip your server/bartender.
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  0           0              544861f7498e54d3775bd639  Marty
# 1  0           0              4edd900a77c8274e00ead77e  Tannah
#
#   user.lastName user.gender   user.id
# 0  Muffler       male        84330972
# 1  Bing          female      7687985

# %% [markdown]
# ## Well, this is going to take some soul-searching. After doing this project, I've learned I want to map a lot of things such as the following:
#
# - CrossFit gym locations
# - Churches in our denomination
# - Senior centers (for the future)
# - State Forests
# - State Trails
#
# I can then visualize the data, or for a more elaborate project, I would cluster the data or use a decision tree algorithm to determine which city may be the best choice.
#
# There's definitely room for expansion of this project in a real world scenario!
#
# It really comes down to personal preference, though, when making a decision like this. Some of that is just gut feelings when visiting the area. We have time to make a decision and can take short trips into Wisconsin in the next few years to actually spend time in these areas.
